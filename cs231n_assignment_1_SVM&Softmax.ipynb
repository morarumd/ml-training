# %% [markdown]
# <a href="https://colab.research.google.com/github/morarumd/ml-training/blob/master/cs231n_assignment_1_SVM%26Softmax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Classifier

# %%
import numpy as np

class LinearClassifier(object):

    def __init__(self):
        self.W = None

    def train(self, X, y, learning_rate=1e-3, reg=1e-5, num_iters=100,
              batch_size=200, verbose=False):
        """
        Train this linear classifier using stochastic gradient descent.

        Inputs:
        - X: A numpy array of shape (N, D) containing training data; there are N
          training samples each of dimension D.
        - y: A numpy array of shape (N,) containing training labels; y[i] = c
          means that X[i] has label 0 <= c < C for C classes.
        - learning_rate: (float) learning rate for optimization.
        - reg: (float) regularization strength.
        - num_iters: (integer) number of steps to take when optimizing
        - batch_size: (integer) number of training examples to use at each step.
        - verbose: (boolean) If true, print progress during optimization.

        Outputs:
        A list containing the value of the loss function at each training iteration.
        """
        num_train, dim = X.shape
        num_classes = np.max(y) + 1 # assume y takes values 0...K-1 where K is number of classes
        if self.W is None:
            # lazily initialize W
            self.W = 0.001 * np.random.randn(dim, num_classes)

        # Run stochastic gradient descent to optimize W
        loss_history = []
        for it in range(num_iters):
            X_batch = None
            y_batch = None

            #########################################################################
            # TODO:                                                                 #
            # Sample batch_size elements from the training data and their           #
            # corresponding labels to use in this round of gradient descent.        #
            # Store the data in X_batch and their corresponding labels in           #
            # y_batch; after sampling X_batch should have shape (batch_size, dim)   #
            # and y_batch should have shape (batch_size,)                           #
            #                                                                       #
            # Hint: Use np.random.choice to generate indices. Sampling with         #
            # replacement is faster than sampling without replacement.              #
            #########################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            indices = np.random.choice(num_train, batch_size, replace=False)
            X_batch = X[indices]
            y_batch = y[indices]

            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            # evaluate loss and gradient
            loss, grad = self.loss(X_batch, y_batch, reg)
            loss_history.append(loss)

            # perform parameter update
            #########################################################################
            # TODO:                                                                 #
            # Update the weights using the gradient and the learning rate.          #
            #########################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            self.W -= learning_rate * grad
            
            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            if verbose and it % 100 == 0:
                print('iteration %d / %d: loss %f' % (it, num_iters, loss))

        return loss_history

    def predict(self, X):
        """
        Use the trained weights of this linear classifier to predict labels for
        data points.

        Inputs:
        - X: A numpy array of shape (N, D) containing training data; there are N
          training samples each of dimension D.

        Returns:
        - y_pred: Predicted labels for the data in X. y_pred is a 1-dimensional
          array of length N, and each element is an integer giving the predicted
          class.
        """
        y_pred = np.zeros(X.shape[0])
        ###########################################################################
        # TODO:                                                                   #
        # Implement this method. Store the predicted labels in y_pred.            #
        ###########################################################################
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        scores = X.dot(self.W)
        y_pred = scores.argmax(axis=1)

        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        return y_pred

    def loss(self, X_batch, y_batch, reg):
        """
        Compute the loss function and its derivative.
        Subclasses will override this.

        Inputs:
        - X_batch: A numpy array of shape (N, D) containing a minibatch of N
          data points; each point has dimension D.
        - y_batch: A numpy array of shape (N,) containing labels for the minibatch.
        - reg: (float) regularization strength.

        Returns: A tuple containing:
        - loss as a single float
        - gradient with respect to self.W; an array of the same shape as W
        """
        pass


class LinearSVM(LinearClassifier):
    """ A subclass that uses the Multiclass SVM loss function """

    def loss(self, X_batch, y_batch, reg):
        return svm_loss_vectorized(self.W, X_batch, y_batch, reg)


class Softmax(LinearClassifier):
    """ A subclass that uses the Softmax + Cross-entropy loss function """

    def loss(self, X_batch, y_batch, reg):
        return softmax_loss_vectorized(self.W, X_batch, y_batch, reg)

# %% [markdown]
# # Gradient Check

# %%
import numpy as np
from random import randrange

def eval_numerical_gradient(f, x, verbose=True, h=0.00001):
    """
    a naive implementation of numerical gradient of f at x
    - f should be a function that takes a single argument
    - x is the point (numpy array) to evaluate the gradient at
    """

    fx = f(x) # evaluate function value at original point
    grad = np.zeros_like(x)
    # iterate over all indexes in x
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:

        # evaluate function at x+h
        ix = it.multi_index
        oldval = x[ix]
        x[ix] = oldval + h # increment by h
        fxph = f(x) # evalute f(x + h)
        x[ix] = oldval - h
        fxmh = f(x) # evaluate f(x - h)
        x[ix] = oldval # restore

        # compute the partial derivative with centered formula
        grad[ix] = (fxph - fxmh) / (2 * h) # the slope
        if verbose:
            print(ix, grad[ix])
        it.iternext() # step to next dimension

    return grad


def eval_numerical_gradient_array(f, x, df, h=1e-5):
    """
    Evaluate a numeric gradient for a function that accepts a numpy
    array and returns a numpy array.
    """
    grad = np.zeros_like(x)
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        ix = it.multi_index

        oldval = x[ix]
        x[ix] = oldval + h
        pos = f(x).copy()
        x[ix] = oldval - h
        neg = f(x).copy()
        x[ix] = oldval

        grad[ix] = np.sum((pos - neg) * df) / (2 * h)
        it.iternext()
    return grad


def eval_numerical_gradient_blobs(f, inputs, output, h=1e-5):
    """
    Compute numeric gradients for a function that operates on input
    and output blobs.

    We assume that f accepts several input blobs as arguments, followed by a
    blob where outputs will be written. For example, f might be called like:

    f(x, w, out)

    where x and w are input Blobs, and the result of f will be written to out.

    Inputs:
    - f: function
    - inputs: tuple of input blobs
    - output: output blob
    - h: step size
    """
    numeric_diffs = []
    for input_blob in inputs:
        diff = np.zeros_like(input_blob.diffs)
        it = np.nditer(input_blob.vals, flags=['multi_index'],
                       op_flags=['readwrite'])
        while not it.finished:
            idx = it.multi_index
            orig = input_blob.vals[idx]

            input_blob.vals[idx] = orig + h
            f(*(inputs + (output,)))
            pos = np.copy(output.vals)
            input_blob.vals[idx] = orig - h
            f(*(inputs + (output,)))
            neg = np.copy(output.vals)
            input_blob.vals[idx] = orig

            diff[idx] = np.sum((pos - neg) * output.diffs) / (2.0 * h)

            it.iternext()
        numeric_diffs.append(diff)
    return numeric_diffs


def eval_numerical_gradient_net(net, inputs, output, h=1e-5):
    return eval_numerical_gradient_blobs(lambda *args: net.forward(),
                inputs, output, h=h)


def grad_check_sparse(f, x, analytic_grad, num_checks=10, h=1e-5):
    """
    sample a few random elements and only return numerical
    in this dimensions.
    """

    for i in range(num_checks):
        ix = tuple([randrange(m) for m in x.shape])

        oldval = x[ix]
        x[ix] = oldval + h # increment by h
        fxph = f(x) # evaluate f(x + h)
        x[ix] = oldval - h # increment by h
        fxmh = f(x) # evaluate f(x - h)
        x[ix] = oldval # reset

        grad_numerical = (fxph - fxmh) / (2 * h)
        grad_analytic = analytic_grad[ix]
        rel_error = (abs(grad_numerical - grad_analytic) /
                    (abs(grad_numerical) + abs(grad_analytic)))
        print('numerical: %f analytic: %f, relative error: %e'
              %(grad_numerical, grad_analytic, rel_error))

# %% [markdown]
# # SVM

# %%
import numpy as np
from random import shuffle

def svm_loss_naive(W, X, y, reg):
    """
    Structured SVM loss function, naive implementation (with loops).

    Inputs have dimension D, there are C classes, and we operate on minibatches
    of N examples.

    Inputs:
    - W: A numpy array of shape (D, C) containing weights.
    - X: A numpy array of shape (N, D) containing a minibatch of data.
    - y: A numpy array of shape (N,) containing training labels; y[i] = c means
      that X[i] has label c, where 0 <= c < C.
    - reg: (float) regularization strength

    Returns a tuple of:
    - loss as single float
    - gradient with respect to weights W; an array of same shape as W
    """
    dW = np.zeros(W.shape) # initialize the gradient as zero

    # compute the loss and the gradient
    num_classes = W.shape[1]
    num_train = X.shape[0]
    loss = 0.0
    for i in range(num_train):
        scores = X[i].dot(W)
        correct_class_score = scores[y[i]]
        for j in range(num_classes):
            if j == y[i]:
                continue
            margin = scores[j] - correct_class_score + 1 # note delta = 1
            if margin > 0:
                loss += margin
                dW[:, y[i]] -= X[i]
                dW[:,j] += X[i]
                

    # Right now the loss is a sum over all training examples, but we want it
    # to be an average instead so we divide by num_train.
    loss /= num_train
    loss += reg * np.sum(W * W)
    
    #############################################################################
    # TODO:                                                                     #
    # Compute the gradient of the loss function and store it dW.                #
    # Rather that first computing the loss and then computing the derivative,   #
    # it may be simpler to compute the derivative at the same time that the     #
    # loss is being computed. As a result you may need to modify some of the    #
    # code above to compute the gradient.                                       #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    dW /= num_train
    dW += 2 * reg * W

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
    return loss, dW



def svm_loss_vectorized(W, X, y, reg):
    """
    Structured SVM loss function, vectorized implementation.

    Inputs and outputs are the same as svm_loss_naive.
    """
    loss = 0.0
    dW = np.zeros(W.shape) # initialize the gradient as zero

    #############################################################################
    # TODO:                                                                     #
    # Implement a vectorized version of the structured SVM loss, storing the    #
    # result in loss.                                                           #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    num_classes = W.shape[1]
    num_train = X.shape[0]
    scores = X.dot(W)
    cci = (np.arange(num_train), y.reshape(-1)) #correct class index
    correct_class_scores = scores[cci[0], cci[1]].reshape(-1, 1)
    margin = np.maximum(0, scores - correct_class_scores + 1)
    margin[cci[0], cci[1]] = 0
    loss = margin.sum() / num_train
    loss += reg * np.sum(W * W)

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    #############################################################################
    # TODO:                                                                     #
    # Implement a vectorized version of the gradient for the structured SVM     #
    # loss, storing the result in dW.                                           #
    #                                                                           #
    # Hint: Instead of computing the gradient from scratch, it may be easier    #
    # to reuse some of the intermediate values that you used to compute the     #
    # loss.                                                                     #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    margin[margin > 0] = 1
    margin[cci[0], cci[1]] -= margin.sum(axis=1)
    dW = X.T.dot(margin) / num_train
    dW += 2 * reg * W

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    return loss, dW

# %% [markdown]
# # Multiclass Support Vector Machine exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.__version__)
# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# # Load the raw CIFAR-10 data.
# cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

# # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
# try:
#    del X_train, y_train
#    del X_test, y_test
#    print('Clear previously loaded data.')
# except:
#    pass

# X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train, X_test = X_train.astype(np.float64), X_test.astype(np.float64)
y_train = y_train.reshape(-1)
y_test = y_test.reshape(-1)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (49000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()

# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# third: append the bias dimension of ones (i.e. bias trick) so that our SVM
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# [130.64189796 135.98173469 132.47391837 130.05569388 135.34804082
#  131.75402041 130.96055102 136.14328571 132.47636735 131.48467347]
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## SVM Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/linear_svm.py**.
#
# As you can see, we have prefilled the function `compute_loss_naive` which uses for loops to evaluate the multiclass SVM loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
# from cs231n.classifiers.linear_svm import svm_loss_naive
import time

# generate a random SVM weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 9.714632

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient correctly, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
# from cs231n.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)

# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: -3.676739 analytic: -3.676739, relative error: 2.920520e-11
# numerical: -20.173377 analytic: -20.173377, relative error: 1.578800e-11
# numerical: 19.889622 analytic: 19.889622, relative error: 1.691545e-12
# numerical: 13.178292 analytic: 13.178292, relative error: 3.706941e-11
# numerical: -10.996297 analytic: -10.996297, relative error: 2.849945e-11
# numerical: 16.211756 analytic: 16.211756, relative error: 2.559759e-11
# numerical: 5.479026 analytic: 5.479026, relative error: 2.452765e-11
# numerical: 10.757772 analytic: 10.757772, relative error: 1.454735e-13
# numerical: 5.989460 analytic: 5.989460, relative error: 3.912497e-11
# numerical: 0.507194 analytic: 0.507194, relative error: 3.520919e-10
# numerical: -32.283593 analytic: -32.283593, relative error: 3.305593e-12
# numerical: 20.746204 analytic: 20.746204, relative error: 5.055966e-12
# numerical: 3.018750 analytic: 3.018750, relative error: 5.451540e-11
# numerical: 12.787710 analytic: 12.787710, relative error: 4.543516e-11
# numerical: 39.639478 analytic: 39.639478, relative error: 3.804519e-12
# numerical: 2.784836 analytic: 2.784836, relative error: 2.549481e-10
# numerical: 38.892157 analytic: 38.892157, relative error: 3.888859e-12
# numerical: -9.121437 analytic: -9.121437, relative error: 4.879246e-12
# numerical: 9.383692 analytic: 9.383692, relative error: 3.464700e-11
# numerical: -2.272835 analytic: -2.272835, relative error: 7.507313e-11

# %% [markdown]
# **Inline Question 1**
#
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? How would change the margin affect of the frequency of this happening? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# $\color{blue}{\textit Your Answer:}$ Numerical gradient is different than the analytic one as the function is not differentiable in 0.

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

# from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 9.053735e+00 computed in 0.181162s
# Vectorized loss: 9.053735e+00 computed in 0.018129s
# difference: 0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.138103s
# Vectorized loss and gradient: computed in 0.009494s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
# from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
# print(X_train.shape, y_train.shape)
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 793.901333
# iteration 100 / 1500: loss 289.125041
# iteration 200 / 1500: loss 108.248575
# iteration 300 / 1500: loss 43.115798
# iteration 400 / 1500: loss 19.316246
# iteration 500 / 1500: loss 10.099467
# iteration 600 / 1500: loss 7.682981
# iteration 700 / 1500: loss 6.732479
# iteration 800 / 1500: loss 5.114596
# iteration 900 / 1500: loss 5.821196
# iteration 1000 / 1500: loss 4.499840
# iteration 1100 / 1500: loss 5.256938
# iteration 1200 / 1500: loss 4.867538
# iteration 1300 / 1500: loss 6.067129
# iteration 1400 / 1500: loss 5.050749
# That took 9.385387s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.364735
# validation accuracy: 0.374000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.39 on the validation set.

#Note: you may see runtime/overflow warnings during hyper-parameter search. 
# This may be caused by extreme values, and is not a bug.

learning_rates = [1e-7, 1e-6]
regularization_strengths = [2e4, 6e4]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for n_iter in range(100):
    lr, rg = np.random.rand(2)
    lr = learning_rates[0] + lr * (learning_rates[1] - learning_rates[0])
    rg = regularization_strengths[0] + rg * (regularization_strengths[1] - regularization_strengths[0])
    print(n_iter, lr, rg)
    svm = LinearSVM()
    svm.train(X_train, y_train, learning_rate=lr, reg=rg,
                        num_iters=1500, verbose=True)

    y_train_pred = svm.predict(X_train)
    train_accuracy = np.mean(y_train == y_train_pred)
    val_accuracy = np.mean(y_val == y_val_pred)
    print('training accuracy: %f' % train_accuracy )
    y_val_pred = svm.predict(X_val)
    print('validation accuracy: %f' % val_accuracy)
    
    results[(lr,rg)] = (train_accuracy, val_accuracy)
    if best_val < val_accuracy:
        best_val = val_accuracy
        best_svm = svm


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 0 1.2430101299341537e-07 30365.850559791026
# iteration 0 / 1500: loss 961.147843
# iteration 100 / 1500: loss 211.130833
# iteration 200 / 1500: loss 49.938421
# iteration 300 / 1500: loss 15.350242
# iteration 400 / 1500: loss 7.210506
# iteration 500 / 1500: loss 6.045256
# iteration 600 / 1500: loss 5.407835
# iteration 700 / 1500: loss 5.942185
# iteration 800 / 1500: loss 5.992855
# iteration 900 / 1500: loss 5.345837
# iteration 1000 / 1500: loss 5.856211
# iteration 1100 / 1500: loss 5.285290
# iteration 1200 / 1500: loss 5.291092
# iteration 1300 / 1500: loss 5.055117
# iteration 1400 / 1500: loss 5.633940
# training accuracy: 0.363184
# validation accuracy: 0.374000
# 1 3.8874783635839877e-07 34487.29095860461
# iteration 0 / 1500: loss 1093.597156
# iteration 100 / 1500: loss 10.037955
# iteration 200 / 1500: loss 5.939762
# iteration 300 / 1500: loss 5.495371
# iteration 400 / 1500: loss 5.768360
# iteration 500 / 1500: loss 5.543828
# iteration 600 / 1500: loss 5.595003
# iteration 700 / 1500: loss 5.636916
# iteration 800 / 1500: loss 5.537195
# iteration 900 / 1500: loss 6.225774
# iteration 1000 / 1500: loss 5.748624
# iteration 1100 / 1500: loss 5.821599
# iteration 1200 / 1500: loss 5.201565
# iteration 1300 / 1500: loss 5.616919
# iteration 1400 / 1500: loss 5.192552
# training accuracy: 0.343388
# validation accuracy: 0.372000
# 2 4.1395351271434905e-07 46248.2385570363
# iteration 0 / 1500: loss 1457.886794
# iteration 100 / 1500: loss 6.776907
# iteration 200 / 1500: loss 6.285826
# iteration 300 / 1500: loss 6.049054
# iteration 400 / 1500: loss 5.795309
# iteration 500 / 1500: loss 6.348795
# iteration 600 / 1500: loss 5.918674
# iteration 700 / 1500: loss 5.969739
# iteration 800 / 1500: loss 6.076703
# iteration 900 / 1500: loss 6.064039
# iteration 1000 / 1500: loss 5.675964
# iteration 1100 / 1500: loss 6.021660
# iteration 1200 / 1500: loss 5.930965
# iteration 1300 / 1500: loss 6.451574
# iteration 1400 / 1500: loss 6.431332
# training accuracy: 0.329286
# validation accuracy: 0.355000
# 3 5.937146566165932e-07 20228.06874130305
# iteration 0 / 1500: loss 641.549327
# iteration 100 / 1500: loss 9.802308
# iteration 200 / 1500: loss 5.401090
# iteration 300 / 1500: loss 5.741585
# iteration 400 / 1500: loss 5.681390
# iteration 500 / 1500: loss 5.685189
# iteration 600 / 1500: loss 6.086649
# iteration 700 / 1500: loss 6.274234
# iteration 800 / 1500: loss 6.241728
# iteration 900 / 1500: loss 6.734632
# iteration 1000 / 1500: loss 5.274640
# iteration 1100 / 1500: loss 5.791884
# iteration 1200 / 1500: loss 5.694088
# iteration 1300 / 1500: loss 6.353128
# iteration 1400 / 1500: loss 6.025705
# training accuracy: 0.336306
# validation accuracy: 0.337000
# 4 9.427724641569453e-07 29073.293044590813
# iteration 0 / 1500: loss 914.914073
# iteration 100 / 1500: loss 6.459486
# iteration 200 / 1500: loss 7.348593
# iteration 300 / 1500: loss 6.402371
# iteration 400 / 1500: loss 6.527870
# iteration 500 / 1500: loss 7.876855
# iteration 600 / 1500: loss 6.622344
# iteration 700 / 1500: loss 6.957903
# iteration 800 / 1500: loss 6.389876
# iteration 900 / 1500: loss 6.832947
# iteration 1000 / 1500: loss 6.628649
# iteration 1100 / 1500: loss 6.398554
# iteration 1200 / 1500: loss 6.279609
# iteration 1300 / 1500: loss 6.210617
# iteration 1400 / 1500: loss 6.389543
# training accuracy: 0.249388
# validation accuracy: 0.327000
# 5 9.531094144245754e-07 56107.58648686208
# iteration 0 / 1500: loss 1774.408121
# iteration 100 / 1500: loss 6.587538
# iteration 200 / 1500: loss 6.783837
# iteration 300 / 1500: loss 6.959635
# iteration 400 / 1500: loss 7.018764
# iteration 500 / 1500: loss 7.207382
# iteration 600 / 1500: loss 7.878502
# iteration 700 / 1500: loss 7.367420
# iteration 800 / 1500: loss 7.563994
# iteration 900 / 1500: loss 8.145650
# iteration 1000 / 1500: loss 8.355659
# iteration 1100 / 1500: loss 7.516877
# iteration 1200 / 1500: loss 6.640444
# iteration 1300 / 1500: loss 7.211367
# iteration 1400 / 1500: loss 6.793106
# training accuracy: 0.287347
# validation accuracy: 0.247000
# 6 2.1879193763553385e-07 35911.190012853986
# iteration 0 / 1500: loss 1124.438424
# iteration 100 / 1500: loss 51.308501
# iteration 200 / 1500: loss 8.068670
# iteration 300 / 1500: loss 5.484746
# iteration 400 / 1500: loss 5.294349
# iteration 500 / 1500: loss 5.698626
# iteration 600 / 1500: loss 5.976174
# iteration 700 / 1500: loss 5.473469
# iteration 800 / 1500: loss 6.073641
# iteration 900 / 1500: loss 5.739015
# iteration 1000 / 1500: loss 5.184625
# iteration 1100 / 1500: loss 5.887598
# iteration 1200 / 1500: loss 5.259243
# iteration 1300 / 1500: loss 6.040912
# iteration 1400 / 1500: loss 5.945872
# training accuracy: 0.361980
# validation accuracy: 0.289000
# 7 7.535055313982304e-07 53336.26338266163
# iteration 0 / 1500: loss 1675.624364
# iteration 100 / 1500: loss 7.009678
# iteration 200 / 1500: loss 6.617976
# iteration 300 / 1500: loss 6.753866
# iteration 400 / 1500: loss 6.193031
# iteration 500 / 1500: loss 7.477945
# iteration 600 / 1500: loss 6.479517
# iteration 700 / 1500: loss 6.918034
# iteration 800 / 1500: loss 6.046385
# iteration 900 / 1500: loss 6.384946
# iteration 1000 / 1500: loss 6.774107
# iteration 1100 / 1500: loss 6.603037
# iteration 1200 / 1500: loss 6.428382
# iteration 1300 / 1500: loss 6.755981
# iteration 1400 / 1500: loss 5.953326
# training accuracy: 0.270735
# validation accuracy: 0.361000
# 8 5.439972575888093e-07 50574.21366491962
# iteration 0 / 1500: loss 1579.363241
# iteration 100 / 1500: loss 6.043284
# iteration 200 / 1500: loss 6.041278
# iteration 300 / 1500: loss 6.027482
# iteration 400 / 1500: loss 6.645697
# iteration 500 / 1500: loss 6.353478
# iteration 600 / 1500: loss 6.271651
# iteration 700 / 1500: loss 5.939184
# iteration 800 / 1500: loss 6.103086
# iteration 900 / 1500: loss 6.190763
# iteration 1000 / 1500: loss 6.079546
# iteration 1100 / 1500: loss 6.391816
# iteration 1200 / 1500: loss 5.461491
# iteration 1300 / 1500: loss 6.139614
# iteration 1400 / 1500: loss 5.688583
# training accuracy: 0.300020
# validation accuracy: 0.283000
# 9 8.34397562872388e-07 26590.38867391446
# iteration 0 / 1500: loss 838.750712
# iteration 100 / 1500: loss 6.950945
# iteration 200 / 1500: loss 6.549253
# iteration 300 / 1500: loss 6.402043
# iteration 400 / 1500: loss 6.678686
# iteration 500 / 1500: loss 6.543106
# iteration 600 / 1500: loss 5.630674
# iteration 700 / 1500: loss 6.953548
# iteration 800 / 1500: loss 6.877276
# iteration 900 / 1500: loss 6.195921
# iteration 1000 / 1500: loss 5.697437
# iteration 1100 / 1500: loss 6.567892
# iteration 1200 / 1500: loss 6.271974
# iteration 1300 / 1500: loss 6.758700
# iteration 1400 / 1500: loss 5.832253
# training accuracy: 0.324939
# validation accuracy: 0.298000
# 10 4.786139891893834e-07 51853.37929414683
# iteration 0 / 1500: loss 1620.883709
# iteration 100 / 1500: loss 6.116066
# iteration 200 / 1500: loss 6.261859
# iteration 300 / 1500: loss 6.639880
# iteration 400 / 1500: loss 5.430800
# iteration 500 / 1500: loss 5.912548
# iteration 600 / 1500: loss 6.047157
# iteration 700 / 1500: loss 5.824165
# iteration 800 / 1500: loss 5.722105
# iteration 900 / 1500: loss 6.262592
# iteration 1000 / 1500: loss 5.690685
# iteration 1100 / 1500: loss 5.837738
# iteration 1200 / 1500: loss 6.209365
# iteration 1300 / 1500: loss 5.800747
# iteration 1400 / 1500: loss 6.150848
# training accuracy: 0.333306
# validation accuracy: 0.326000
# 11 1.4492222043588957e-07 49738.82687943318
# iteration 0 / 1500: loss 1544.837540
# iteration 100 / 1500: loss 88.265711
# iteration 200 / 1500: loss 10.028180
# iteration 300 / 1500: loss 6.490211
# iteration 400 / 1500: loss 5.436368
# iteration 500 / 1500: loss 5.630531
# iteration 600 / 1500: loss 5.521079
# iteration 700 / 1500: loss 5.611542
# iteration 800 / 1500: loss 5.938502
# iteration 900 / 1500: loss 5.698885
# iteration 1000 / 1500: loss 5.340527
# iteration 1100 / 1500: loss 5.015381
# iteration 1200 / 1500: loss 5.860292
# iteration 1300 / 1500: loss 5.215215
# iteration 1400 / 1500: loss 5.563566
# training accuracy: 0.362286
# validation accuracy: 0.355000
# 12 4.120330507653738e-07 56445.329389465005
# iteration 0 / 1500: loss 1733.660731
# iteration 100 / 1500: loss 6.417387
# iteration 200 / 1500: loss 6.004491
# iteration 300 / 1500: loss 6.398213
# iteration 400 / 1500: loss 6.150826
# iteration 500 / 1500: loss 5.932596
# iteration 600 / 1500: loss 5.358682
# iteration 700 / 1500: loss 6.201829
# iteration 800 / 1500: loss 5.513826
# iteration 900 / 1500: loss 5.643954
# iteration 1000 / 1500: loss 6.296385
# iteration 1100 / 1500: loss 6.379105
# iteration 1200 / 1500: loss 5.656660
# iteration 1300 / 1500: loss 6.137088
# iteration 1400 / 1500: loss 5.979407
# training accuracy: 0.322857
# validation accuracy: 0.376000
# 13 9.87369004638426e-07 43047.58407722067
# iteration 0 / 1500: loss 1379.853497
# iteration 100 / 1500: loss 9.000726
# iteration 200 / 1500: loss 7.252047
# iteration 300 / 1500: loss 7.492390
# iteration 400 / 1500: loss 6.770513
# iteration 500 / 1500: loss 6.928368
# iteration 600 / 1500: loss 6.967946
# iteration 700 / 1500: loss 7.180875
# iteration 800 / 1500: loss 6.818415
# iteration 900 / 1500: loss 6.208188
# iteration 1000 / 1500: loss 7.959213
# iteration 1100 / 1500: loss 6.640042
# iteration 1200 / 1500: loss 6.874705
# iteration 1300 / 1500: loss 6.859907
# iteration 1400 / 1500: loss 7.512320
# training accuracy: 0.299837
# validation accuracy: 0.330000
# 14 2.199627001774829e-07 34803.52362450163
# iteration 0 / 1500: loss 1101.925686
# iteration 100 / 1500: loss 53.624969
# iteration 200 / 1500: loss 7.993713
# iteration 300 / 1500: loss 5.536671
# iteration 400 / 1500: loss 5.440410
# iteration 500 / 1500: loss 5.238051
# iteration 600 / 1500: loss 5.527588
# iteration 700 / 1500: loss 5.375325
# iteration 800 / 1500: loss 5.548790
# iteration 900 / 1500: loss 5.526425
# iteration 1000 / 1500: loss 6.236850
# iteration 1100 / 1500: loss 5.710491
# iteration 1200 / 1500: loss 5.409734
# iteration 1300 / 1500: loss 5.837022
# iteration 1400 / 1500: loss 5.582840
# training accuracy: 0.358265
# validation accuracy: 0.312000
# 15 7.133139809707399e-07 53616.341272849866
# iteration 0 / 1500: loss 1657.349456
# iteration 100 / 1500: loss 7.017333
# iteration 200 / 1500: loss 6.113655
# iteration 300 / 1500: loss 6.502317
# iteration 400 / 1500: loss 6.127451
# iteration 500 / 1500: loss 6.236675
# iteration 600 / 1500: loss 6.630173
# iteration 700 / 1500: loss 7.288132
# iteration 800 / 1500: loss 6.457023
# iteration 900 / 1500: loss 6.453538
# iteration 1000 / 1500: loss 7.474429
# iteration 1100 / 1500: loss 5.822488
# iteration 1200 / 1500: loss 6.519968
# iteration 1300 / 1500: loss 6.635321
# iteration 1400 / 1500: loss 6.443809
# training accuracy: 0.285592
# validation accuracy: 0.350000
# 16 7.330135608866722e-07 28868.38930160377
# iteration 0 / 1500: loss 913.811162
# iteration 100 / 1500: loss 7.543728
# iteration 200 / 1500: loss 6.162342
# iteration 300 / 1500: loss 7.496900
# iteration 400 / 1500: loss 6.576049
# iteration 500 / 1500: loss 6.621152
# iteration 600 / 1500: loss 5.836172
# iteration 700 / 1500: loss 5.363701
# iteration 800 / 1500: loss 6.324636
# iteration 900 / 1500: loss 5.801414
# iteration 1000 / 1500: loss 6.488137
# iteration 1100 / 1500: loss 6.015826
# iteration 1200 / 1500: loss 5.609012
# iteration 1300 / 1500: loss 6.345180
# iteration 1400 / 1500: loss 6.020137
# training accuracy: 0.279816
# validation accuracy: 0.291000
# 17 8.61908066984827e-07 28771.28963117038
# iteration 0 / 1500: loss 906.591107
# iteration 100 / 1500: loss 6.220893
# iteration 200 / 1500: loss 6.267247
# iteration 300 / 1500: loss 6.022432
# iteration 400 / 1500: loss 6.067685
# iteration 500 / 1500: loss 6.528625
# iteration 600 / 1500: loss 6.072987
# iteration 700 / 1500: loss 5.935637
# iteration 800 / 1500: loss 6.660481
# iteration 900 / 1500: loss 6.156610
# iteration 1000 / 1500: loss 7.261153
# iteration 1100 / 1500: loss 5.799192
# iteration 1200 / 1500: loss 6.920138
# iteration 1300 / 1500: loss 6.886050
# iteration 1400 / 1500: loss 6.047511
# training accuracy: 0.288571
# validation accuracy: 0.286000
# 18 4.878856492712917e-07 50185.461569129446
# iteration 0 / 1500: loss 1555.216866
# iteration 100 / 1500: loss 6.377167
# iteration 200 / 1500: loss 6.414883
# iteration 300 / 1500: loss 5.987424
# iteration 400 / 1500: loss 6.044934
# iteration 500 / 1500: loss 5.920769
# iteration 600 / 1500: loss 5.370898
# iteration 700 / 1500: loss 6.020124
# iteration 800 / 1500: loss 5.948685
# iteration 900 / 1500: loss 5.988063
# iteration 1000 / 1500: loss 5.944651
# iteration 1100 / 1500: loss 5.671395
# iteration 1200 / 1500: loss 6.175612
# iteration 1300 / 1500: loss 6.163662
# iteration 1400 / 1500: loss 5.418306
# training accuracy: 0.319551
# validation accuracy: 0.305000
# 19 8.041958605288399e-07 37624.15184184646
# iteration 0 / 1500: loss 1171.238555
# iteration 100 / 1500: loss 5.516199
# iteration 200 / 1500: loss 6.274283
# iteration 300 / 1500: loss 7.231286
# iteration 400 / 1500: loss 6.487609
# iteration 500 / 1500: loss 6.599890
# iteration 600 / 1500: loss 6.938937
# iteration 700 / 1500: loss 6.139883
# iteration 800 / 1500: loss 6.263473
# iteration 900 / 1500: loss 6.411560
# iteration 1000 / 1500: loss 6.879323
# iteration 1100 / 1500: loss 6.779683
# iteration 1200 / 1500: loss 6.445402
# iteration 1300 / 1500: loss 5.960896
# iteration 1400 / 1500: loss 5.903480
# training accuracy: 0.302612
# validation accuracy: 0.333000
# 20 3.6998311899831734e-07 37651.70059243067
# iteration 0 / 1500: loss 1184.715605
# iteration 100 / 1500: loss 9.553491
# iteration 200 / 1500: loss 5.778563
# iteration 300 / 1500: loss 6.073191
# iteration 400 / 1500: loss 5.708759
# iteration 500 / 1500: loss 5.952270
# iteration 600 / 1500: loss 5.442253
# iteration 700 / 1500: loss 5.536365
# iteration 800 / 1500: loss 5.505307
# iteration 900 / 1500: loss 5.902748
# iteration 1000 / 1500: loss 5.924413
# iteration 1100 / 1500: loss 5.550880
# iteration 1200 / 1500: loss 5.795903
# iteration 1300 / 1500: loss 5.398053
# iteration 1400 / 1500: loss 5.385125
# training accuracy: 0.329592
# validation accuracy: 0.307000
# 21 5.146184489733231e-07 39069.007777468236
# iteration 0 / 1500: loss 1230.024308
# iteration 100 / 1500: loss 5.652127
# iteration 200 / 1500: loss 5.393135
# iteration 300 / 1500: loss 6.588115
# iteration 400 / 1500: loss 5.524490
# iteration 500 / 1500: loss 5.668187
# iteration 600 / 1500: loss 6.498244
# iteration 700 / 1500: loss 5.579879
# iteration 800 / 1500: loss 5.940975
# iteration 900 / 1500: loss 5.905877
# iteration 1000 / 1500: loss 6.064703
# iteration 1100 / 1500: loss 6.708640
# iteration 1200 / 1500: loss 5.840457
# iteration 1300 / 1500: loss 5.915551
# iteration 1400 / 1500: loss 5.596390
# training accuracy: 0.326469
# validation accuracy: 0.329000
# 22 9.553573352892623e-07 59897.36241011467
# iteration 0 / 1500: loss 1856.216507
# iteration 100 / 1500: loss 7.262737
# iteration 200 / 1500: loss 6.774247
# iteration 300 / 1500: loss 6.612073
# iteration 400 / 1500: loss 7.837611
# iteration 500 / 1500: loss 7.684468
# iteration 600 / 1500: loss 7.148247
# iteration 700 / 1500: loss 6.891196
# iteration 800 / 1500: loss 7.071986
# iteration 900 / 1500: loss 7.050587
# iteration 1000 / 1500: loss 7.701074
# iteration 1100 / 1500: loss 8.426265
# iteration 1200 / 1500: loss 7.120053
# iteration 1300 / 1500: loss 7.178538
# iteration 1400 / 1500: loss 7.537880
# training accuracy: 0.265224
# validation accuracy: 0.333000
# 23 6.322058764807751e-07 29608.095673537107
# iteration 0 / 1500: loss 925.889179
# iteration 100 / 1500: loss 6.814941
# iteration 200 / 1500: loss 6.069280
# iteration 300 / 1500: loss 5.558780
# iteration 400 / 1500: loss 5.936331
# iteration 500 / 1500: loss 6.340197
# iteration 600 / 1500: loss 6.336907
# iteration 700 / 1500: loss 6.383703
# iteration 800 / 1500: loss 6.449239
# iteration 900 / 1500: loss 5.889472
# iteration 1000 / 1500: loss 6.651998
# iteration 1100 / 1500: loss 6.321341
# iteration 1200 / 1500: loss 6.009198
# iteration 1300 / 1500: loss 5.703418
# iteration 1400 / 1500: loss 5.202048
# training accuracy: 0.311102
# validation accuracy: 0.283000
# 24 8.454995545374835e-07 56150.62194286909
# iteration 0 / 1500: loss 1719.856087
# iteration 100 / 1500: loss 7.189748
# iteration 200 / 1500: loss 7.590261
# iteration 300 / 1500: loss 7.220200
# iteration 400 / 1500: loss 7.113043
# iteration 500 / 1500: loss 6.670486
# iteration 600 / 1500: loss 7.255286
# iteration 700 / 1500: loss 6.068951
# iteration 800 / 1500: loss 7.291856
# iteration 900 / 1500: loss 6.515857
# iteration 1000 / 1500: loss 7.403886
# iteration 1100 / 1500: loss 7.693671
# iteration 1200 / 1500: loss 6.221315
# iteration 1300 / 1500: loss 7.632915
# iteration 1400 / 1500: loss 7.736590
# training accuracy: 0.278122
# validation accuracy: 0.322000
# 25 3.992804632362972e-07 31373.792002970556
# iteration 0 / 1500: loss 990.261654
# iteration 100 / 1500: loss 11.305463
# iteration 200 / 1500: loss 5.020807
# iteration 300 / 1500: loss 6.107015
# iteration 400 / 1500: loss 5.665810
# iteration 500 / 1500: loss 6.198106
# iteration 600 / 1500: loss 5.611819
# iteration 700 / 1500: loss 5.248019
# iteration 800 / 1500: loss 5.432648
# iteration 900 / 1500: loss 5.384417
# iteration 1000 / 1500: loss 5.355784
# iteration 1100 / 1500: loss 5.553638
# iteration 1200 / 1500: loss 6.104855
# iteration 1300 / 1500: loss 5.726783
# iteration 1400 / 1500: loss 5.862228
# training accuracy: 0.343837
# validation accuracy: 0.283000
# 26 6.944785797245731e-07 53434.675510570356
# iteration 0 / 1500: loss 1645.713878
# iteration 100 / 1500: loss 6.476788
# iteration 200 / 1500: loss 6.217441
# iteration 300 / 1500: loss 6.806348
# iteration 400 / 1500: loss 6.333375
# iteration 500 / 1500: loss 6.123545
# iteration 600 / 1500: loss 6.968096
# iteration 700 / 1500: loss 6.182614
# iteration 800 / 1500: loss 6.535797
# iteration 900 / 1500: loss 6.269962
# iteration 1000 / 1500: loss 7.000019
# iteration 1100 / 1500: loss 6.656096
# iteration 1200 / 1500: loss 6.191144
# iteration 1300 / 1500: loss 7.082139
# iteration 1400 / 1500: loss 6.053498
# training accuracy: 0.289408
# validation accuracy: 0.351000
# 27 6.682412629675557e-07 41329.94815705189
# iteration 0 / 1500: loss 1305.485686
# iteration 100 / 1500: loss 6.228961
# iteration 200 / 1500: loss 6.351174
# iteration 300 / 1500: loss 6.029711
# iteration 400 / 1500: loss 6.116521
# iteration 500 / 1500: loss 5.817509
# iteration 600 / 1500: loss 6.727018
# iteration 700 / 1500: loss 6.447845
# iteration 800 / 1500: loss 6.285963
# iteration 900 / 1500: loss 6.711354
# iteration 1000 / 1500: loss 5.982321
# iteration 1100 / 1500: loss 5.668796
# iteration 1200 / 1500: loss 6.247284
# iteration 1300 / 1500: loss 5.901649
# iteration 1400 / 1500: loss 5.964042
# training accuracy: 0.300551
# validation accuracy: 0.306000
# 28 1.6407640641580451e-07 25256.85822969194
# iteration 0 / 1500: loss 799.708064
# iteration 100 / 1500: loss 152.493008
# iteration 200 / 1500: loss 33.441606
# iteration 300 / 1500: loss 10.192536
# iteration 400 / 1500: loss 6.284337
# iteration 500 / 1500: loss 5.404144
# iteration 600 / 1500: loss 5.488227
# iteration 700 / 1500: loss 5.423372
# iteration 800 / 1500: loss 5.423933
# iteration 900 / 1500: loss 5.513963
# iteration 1000 / 1500: loss 5.520292
# iteration 1100 / 1500: loss 5.116934
# iteration 1200 / 1500: loss 5.320106
# iteration 1300 / 1500: loss 4.491510
# iteration 1400 / 1500: loss 5.184587
# training accuracy: 0.369327
# validation accuracy: 0.307000
# 29 2.3411817144887134e-07 50989.557371305375
# iteration 0 / 1500: loss 1583.556249
# iteration 100 / 1500: loss 18.358071
# iteration 200 / 1500: loss 5.985604
# iteration 300 / 1500: loss 5.490049
# iteration 400 / 1500: loss 6.089981
# iteration 500 / 1500: loss 6.510806
# iteration 600 / 1500: loss 5.893692
# iteration 700 / 1500: loss 6.024003
# iteration 800 / 1500: loss 6.396353
# iteration 900 / 1500: loss 5.976078
# iteration 1000 / 1500: loss 6.058016
# iteration 1100 / 1500: loss 5.655408
# iteration 1200 / 1500: loss 5.751235
# iteration 1300 / 1500: loss 5.766854
# iteration 1400 / 1500: loss 5.624989
# training accuracy: 0.348082
# validation accuracy: 0.389000
# 30 6.038484206543565e-07 27730.641198511643
# iteration 0 / 1500: loss 874.710991
# iteration 100 / 1500: loss 7.278046
# iteration 200 / 1500: loss 6.071715
# iteration 300 / 1500: loss 5.390893
# iteration 400 / 1500: loss 5.889247
# iteration 500 / 1500: loss 5.880482
# iteration 600 / 1500: loss 5.925507
# iteration 700 / 1500: loss 6.183955
# iteration 800 / 1500: loss 5.537746
# iteration 900 / 1500: loss 6.807257
# iteration 1000 / 1500: loss 5.944342
# iteration 1100 / 1500: loss 6.146207
# iteration 1200 / 1500: loss 5.240920
# iteration 1300 / 1500: loss 6.191517
# iteration 1400 / 1500: loss 5.537893
# training accuracy: 0.300816
# validation accuracy: 0.353000
# 31 1.0757098259174879e-07 21499.446170356052
# iteration 0 / 1500: loss 670.473406
# iteration 100 / 1500: loss 264.222276
# iteration 200 / 1500: loss 107.022202
# iteration 300 / 1500: loss 44.664705
# iteration 400 / 1500: loss 20.616333
# iteration 500 / 1500: loss 10.739222
# iteration 600 / 1500: loss 7.938982
# iteration 700 / 1500: loss 6.065803
# iteration 800 / 1500: loss 6.044093
# iteration 900 / 1500: loss 5.077596
# iteration 1000 / 1500: loss 5.315783
# iteration 1100 / 1500: loss 5.217466
# iteration 1200 / 1500: loss 5.539612
# iteration 1300 / 1500: loss 5.232515
# iteration 1400 / 1500: loss 5.192923
# training accuracy: 0.369959
# validation accuracy: 0.315000
# 32 6.441250318804251e-07 39015.33764020998
# iteration 0 / 1500: loss 1227.946558
# iteration 100 / 1500: loss 6.147302
# iteration 200 / 1500: loss 6.382163
# iteration 300 / 1500: loss 6.528656
# iteration 400 / 1500: loss 6.208908
# iteration 500 / 1500: loss 5.846343
# iteration 600 / 1500: loss 6.291735
# iteration 700 / 1500: loss 6.591980
# iteration 800 / 1500: loss 6.559560
# iteration 900 / 1500: loss 6.444492
# iteration 1000 / 1500: loss 6.457065
# iteration 1100 / 1500: loss 6.912887
# iteration 1200 / 1500: loss 6.113289
# iteration 1300 / 1500: loss 6.351567
# iteration 1400 / 1500: loss 5.763536
# training accuracy: 0.307347
# validation accuracy: 0.372000
# 33 3.598067857115426e-07 48530.68645405923
# iteration 0 / 1500: loss 1525.248609
# iteration 100 / 1500: loss 7.255733
# iteration 200 / 1500: loss 5.972360
# iteration 300 / 1500: loss 5.868030
# iteration 400 / 1500: loss 5.482831
# iteration 500 / 1500: loss 5.910377
# iteration 600 / 1500: loss 5.888643
# iteration 700 / 1500: loss 5.543058
# iteration 800 / 1500: loss 6.388696
# iteration 900 / 1500: loss 6.287343
# iteration 1000 / 1500: loss 5.942490
# iteration 1100 / 1500: loss 5.428051
# iteration 1200 / 1500: loss 6.053980
# iteration 1300 / 1500: loss 5.879373
# iteration 1400 / 1500: loss 6.100674
# training accuracy: 0.331204
# validation accuracy: 0.331000
# 34 2.4019167046481823e-07 37508.23527319585
# iteration 0 / 1500: loss 1183.106419
# iteration 100 / 1500: loss 36.551040
# iteration 200 / 1500: loss 6.359685
# iteration 300 / 1500: loss 5.400764
# iteration 400 / 1500: loss 5.180654
# iteration 500 / 1500: loss 5.626103
# iteration 600 / 1500: loss 5.691701
# iteration 700 / 1500: loss 6.656040
# iteration 800 / 1500: loss 6.295726
# iteration 900 / 1500: loss 5.402887
# iteration 1000 / 1500: loss 5.795493
# iteration 1100 / 1500: loss 5.988827
# iteration 1200 / 1500: loss 5.607547
# iteration 1300 / 1500: loss 5.233660
# iteration 1400 / 1500: loss 5.783055
# training accuracy: 0.349878
# validation accuracy: 0.326000
# 35 1.5817319939579507e-07 20045.122345248525
# iteration 0 / 1500: loss 642.256815
# iteration 100 / 1500: loss 179.469266
# iteration 200 / 1500: loss 53.076756
# iteration 300 / 1500: loss 18.554712
# iteration 400 / 1500: loss 9.723385
# iteration 500 / 1500: loss 6.766741
# iteration 600 / 1500: loss 5.233689
# iteration 700 / 1500: loss 6.025192
# iteration 800 / 1500: loss 5.063633
# iteration 900 / 1500: loss 5.162504
# iteration 1000 / 1500: loss 5.682544
# iteration 1100 / 1500: loss 4.978746
# iteration 1200 / 1500: loss 5.394662
# iteration 1300 / 1500: loss 5.150152
# iteration 1400 / 1500: loss 5.289792
# training accuracy: 0.367878
# validation accuracy: 0.375000
# 36 7.536128268364418e-07 51468.022841928105
# iteration 0 / 1500: loss 1610.298075
# iteration 100 / 1500: loss 6.040851
# iteration 200 / 1500: loss 6.859364
# iteration 300 / 1500: loss 7.048593
# iteration 400 / 1500: loss 7.494695
# iteration 500 / 1500: loss 6.528133
# iteration 600 / 1500: loss 6.977721
# iteration 700 / 1500: loss 5.979208
# iteration 800 / 1500: loss 6.431421
# iteration 900 / 1500: loss 7.455891
# iteration 1000 / 1500: loss 6.265306
# iteration 1100 / 1500: loss 6.257142
# iteration 1200 / 1500: loss 6.305993
# iteration 1300 / 1500: loss 6.913030
# iteration 1400 / 1500: loss 6.645390
# training accuracy: 0.307122
# validation accuracy: 0.376000
# 37 9.442797285221409e-07 34026.35201229184
# iteration 0 / 1500: loss 1064.100962
# iteration 100 / 1500: loss 7.112045
# iteration 200 / 1500: loss 7.591662
# iteration 300 / 1500: loss 6.209781
# iteration 400 / 1500: loss 7.060682
# iteration 500 / 1500: loss 6.177108
# iteration 600 / 1500: loss 6.480277
# iteration 700 / 1500: loss 6.719238
# iteration 800 / 1500: loss 7.566571
# iteration 900 / 1500: loss 6.114324
# iteration 1000 / 1500: loss 6.442817
# iteration 1100 / 1500: loss 8.648216
# iteration 1200 / 1500: loss 7.013675
# iteration 1300 / 1500: loss 7.363458
# iteration 1400 / 1500: loss 6.723717
# training accuracy: 0.278102
# validation accuracy: 0.319000
# 38 3.0339415736061254e-07 49225.246290350944
# iteration 0 / 1500: loss 1542.722107
# iteration 100 / 1500: loss 8.855826
# iteration 200 / 1500: loss 5.948319
# iteration 300 / 1500: loss 5.635412
# iteration 400 / 1500: loss 5.641062
# iteration 500 / 1500: loss 6.028822
# iteration 600 / 1500: loss 5.487958
# iteration 700 / 1500: loss 6.169359
# iteration 800 / 1500: loss 5.578876
# iteration 900 / 1500: loss 5.648152
# iteration 1000 / 1500: loss 6.002994
# iteration 1100 / 1500: loss 6.765606
# iteration 1200 / 1500: loss 5.788137
# iteration 1300 / 1500: loss 5.731659
# iteration 1400 / 1500: loss 5.881032
# training accuracy: 0.340388
# validation accuracy: 0.283000
# 39 8.303783914186672e-07 54782.39280937151
# iteration 0 / 1500: loss 1696.433816
# iteration 100 / 1500: loss 7.078737
# iteration 200 / 1500: loss 7.661781
# iteration 300 / 1500: loss 6.679047
# iteration 400 / 1500: loss 6.716029
# iteration 500 / 1500: loss 7.123071
# iteration 600 / 1500: loss 6.907386
# iteration 700 / 1500: loss 6.629045
# iteration 800 / 1500: loss 6.949337
# iteration 900 / 1500: loss 6.829913
# iteration 1000 / 1500: loss 7.038117
# iteration 1100 / 1500: loss 6.706519
# iteration 1200 / 1500: loss 7.289075
# iteration 1300 / 1500: loss 6.534679
# iteration 1400 / 1500: loss 6.448992
# training accuracy: 0.283714
# validation accuracy: 0.356000
# 40 3.879029066511784e-07 54093.16581921162
# iteration 0 / 1500: loss 1690.167188
# iteration 100 / 1500: loss 6.368596
# iteration 200 / 1500: loss 6.579866
# iteration 300 / 1500: loss 5.957005
# iteration 400 / 1500: loss 5.580869
# iteration 500 / 1500: loss 6.318749
# iteration 600 / 1500: loss 5.930818
# iteration 700 / 1500: loss 5.768314
# iteration 800 / 1500: loss 5.607399
# iteration 900 / 1500: loss 5.959852
# iteration 1000 / 1500: loss 5.911061
# iteration 1100 / 1500: loss 6.412248
# iteration 1200 / 1500: loss 6.645416
# iteration 1300 / 1500: loss 6.701216
# iteration 1400 / 1500: loss 5.760482
# training accuracy: 0.336796
# validation accuracy: 0.283000
# 41 8.819142894379909e-07 20460.092146926625
# iteration 0 / 1500: loss 646.307025
# iteration 100 / 1500: loss 6.554831
# iteration 200 / 1500: loss 6.672267
# iteration 300 / 1500: loss 6.846522
# iteration 400 / 1500: loss 6.927437
# iteration 500 / 1500: loss 6.652220
# iteration 600 / 1500: loss 5.426289
# iteration 700 / 1500: loss 5.861804
# iteration 800 / 1500: loss 6.293782
# iteration 900 / 1500: loss 6.902339
# iteration 1000 / 1500: loss 6.255562
# iteration 1100 / 1500: loss 6.944555
# iteration 1200 / 1500: loss 5.182899
# iteration 1300 / 1500: loss 6.270900
# iteration 1400 / 1500: loss 6.391826
# training accuracy: 0.318286
# validation accuracy: 0.357000
# 42 3.8920821596597126e-07 39564.51939381969
# iteration 0 / 1500: loss 1238.975679
# iteration 100 / 1500: loss 7.995937
# iteration 200 / 1500: loss 5.978430
# iteration 300 / 1500: loss 5.854818
# iteration 400 / 1500: loss 6.240321
# iteration 500 / 1500: loss 5.506036
# iteration 600 / 1500: loss 6.302014
# iteration 700 / 1500: loss 5.808847
# iteration 800 / 1500: loss 5.840612
# iteration 900 / 1500: loss 5.768336
# iteration 1000 / 1500: loss 6.404904
# iteration 1100 / 1500: loss 6.631810
# iteration 1200 / 1500: loss 5.674363
# iteration 1300 / 1500: loss 6.173274
# iteration 1400 / 1500: loss 6.630257
# training accuracy: 0.334020
# validation accuracy: 0.331000
# 43 5.837620285930834e-07 48066.092961122966
# iteration 0 / 1500: loss 1482.824765
# iteration 100 / 1500: loss 5.815870
# iteration 200 / 1500: loss 6.392714
# iteration 300 / 1500: loss 7.105056
# iteration 400 / 1500: loss 6.297092
# iteration 500 / 1500: loss 6.665468
# iteration 600 / 1500: loss 6.850959
# iteration 700 / 1500: loss 6.566301
# iteration 800 / 1500: loss 6.132795
# iteration 900 / 1500: loss 6.338094
# iteration 1000 / 1500: loss 6.067098
# iteration 1100 / 1500: loss 5.790290
# iteration 1200 / 1500: loss 6.181136
# iteration 1300 / 1500: loss 6.905190
# iteration 1400 / 1500: loss 6.561809
# training accuracy: 0.271490
# validation accuracy: 0.339000
# 44 9.128796541583603e-07 40686.168096513094
# iteration 0 / 1500: loss 1287.102119
# iteration 100 / 1500: loss 6.833071
# iteration 200 / 1500: loss 7.252163
# iteration 300 / 1500: loss 6.820720
# iteration 400 / 1500: loss 6.241381
# iteration 500 / 1500: loss 6.208865
# iteration 600 / 1500: loss 6.141826
# iteration 700 / 1500: loss 7.413134
# iteration 800 / 1500: loss 6.051645
# iteration 900 / 1500: loss 6.579107
# iteration 1000 / 1500: loss 7.197570
# iteration 1100 / 1500: loss 5.724345
# iteration 1200 / 1500: loss 7.429511
# iteration 1300 / 1500: loss 6.230633
# iteration 1400 / 1500: loss 6.886564
# training accuracy: 0.277592
# validation accuracy: 0.270000
# 45 2.30301364433361e-07 56840.26931070294
# iteration 0 / 1500: loss 1755.338442
# iteration 100 / 1500: loss 14.291336
# iteration 200 / 1500: loss 6.050087
# iteration 300 / 1500: loss 6.022007
# iteration 400 / 1500: loss 5.974173
# iteration 500 / 1500: loss 5.980559
# iteration 600 / 1500: loss 5.904978
# iteration 700 / 1500: loss 5.729567
# iteration 800 / 1500: loss 5.733666
# iteration 900 / 1500: loss 5.783914
# iteration 1000 / 1500: loss 5.863183
# iteration 1100 / 1500: loss 5.187100
# iteration 1200 / 1500: loss 6.037215
# iteration 1300 / 1500: loss 6.083727
# iteration 1400 / 1500: loss 5.694667
# training accuracy: 0.346449
# validation accuracy: 0.303000
# 46 6.975072100600742e-07 34267.31035180057
# iteration 0 / 1500: loss 1058.864675
# iteration 100 / 1500: loss 5.666483
# iteration 200 / 1500: loss 6.221680
# iteration 300 / 1500: loss 6.277414
# iteration 400 / 1500: loss 5.791419
# iteration 500 / 1500: loss 6.922832
# iteration 600 / 1500: loss 5.802017
# iteration 700 / 1500: loss 7.606224
# iteration 800 / 1500: loss 6.498254
# iteration 900 / 1500: loss 6.160184
# iteration 1000 / 1500: loss 6.940087
# iteration 1100 / 1500: loss 6.286423
# iteration 1200 / 1500: loss 6.967550
# iteration 1300 / 1500: loss 7.170997
# iteration 1400 / 1500: loss 6.345632
# training accuracy: 0.335653
# validation accuracy: 0.364000
# 47 2.670296278166169e-07 41932.38377444219
# iteration 0 / 1500: loss 1321.796466
# iteration 100 / 1500: loss 20.398673
# iteration 200 / 1500: loss 5.804452
# iteration 300 / 1500: loss 5.515148
# iteration 400 / 1500: loss 5.680057
# iteration 500 / 1500: loss 5.602368
# iteration 600 / 1500: loss 5.905994
# iteration 700 / 1500: loss 5.459279
# iteration 800 / 1500: loss 6.092534
# iteration 900 / 1500: loss 5.961604
# iteration 1000 / 1500: loss 5.712012
# iteration 1100 / 1500: loss 5.867631
# iteration 1200 / 1500: loss 5.792927
# iteration 1300 / 1500: loss 5.083123
# iteration 1400 / 1500: loss 5.589591
# training accuracy: 0.344837
# validation accuracy: 0.355000
# 48 9.426773518378824e-07 46634.85411235594
# iteration 0 / 1500: loss 1474.395606
# iteration 100 / 1500: loss 7.678129
# iteration 200 / 1500: loss 7.492142
# iteration 300 / 1500: loss 6.627989
# iteration 400 / 1500: loss 7.482459
# iteration 500 / 1500: loss 7.163628
# iteration 600 / 1500: loss 7.131166
# iteration 700 / 1500: loss 7.833868
# iteration 800 / 1500: loss 6.610315
# iteration 900 / 1500: loss 6.327223
# iteration 1000 / 1500: loss 8.145932
# iteration 1100 / 1500: loss 7.786539
# iteration 1200 / 1500: loss 7.506058
# iteration 1300 / 1500: loss 6.632430
# iteration 1400 / 1500: loss 7.449726
# training accuracy: 0.283327
# validation accuracy: 0.351000
# 49 8.71321541959751e-07 58102.77709336006
# iteration 0 / 1500: loss 1794.645755
# iteration 100 / 1500: loss 6.207032
# iteration 200 / 1500: loss 6.498706
# iteration 300 / 1500: loss 8.082414
# iteration 400 / 1500: loss 8.458543
# iteration 500 / 1500: loss 6.773841
# iteration 600 / 1500: loss 6.724236
# iteration 700 / 1500: loss 7.080553
# iteration 800 / 1500: loss 6.683539
# iteration 900 / 1500: loss 7.872492
# iteration 1000 / 1500: loss 6.522386
# iteration 1100 / 1500: loss 6.975360
# iteration 1200 / 1500: loss 7.303590
# iteration 1300 / 1500: loss 6.406379
# iteration 1400 / 1500: loss 6.582892
# training accuracy: 0.283510
# validation accuracy: 0.296000
# 50 1.3440704939567713e-07 40961.19709729332
# iteration 0 / 1500: loss 1297.738044
# iteration 100 / 1500: loss 144.401831
# iteration 200 / 1500: loss 20.643277
# iteration 300 / 1500: loss 7.132762
# iteration 400 / 1500: loss 5.111890
# iteration 500 / 1500: loss 5.505364
# iteration 600 / 1500: loss 5.313355
# iteration 700 / 1500: loss 5.447436
# iteration 800 / 1500: loss 5.769890
# iteration 900 / 1500: loss 5.468572
# iteration 1000 / 1500: loss 5.557352
# iteration 1100 / 1500: loss 5.774072
# iteration 1200 / 1500: loss 5.299730
# iteration 1300 / 1500: loss 5.294218
# iteration 1400 / 1500: loss 5.491757
# training accuracy: 0.359755
# validation accuracy: 0.275000
# 51 6.271834321578055e-07 38849.33635633298
# iteration 0 / 1500: loss 1220.020387
# iteration 100 / 1500: loss 6.474977
# iteration 200 / 1500: loss 5.675624
# iteration 300 / 1500: loss 6.490683
# iteration 400 / 1500: loss 5.874344
# iteration 500 / 1500: loss 6.113112
# iteration 600 / 1500: loss 5.845787
# iteration 700 / 1500: loss 7.164444
# iteration 800 / 1500: loss 6.134556
# iteration 900 / 1500: loss 6.401208
# iteration 1000 / 1500: loss 6.423673
# iteration 1100 / 1500: loss 6.374993
# iteration 1200 / 1500: loss 5.659917
# iteration 1300 / 1500: loss 6.978494
# iteration 1400 / 1500: loss 5.754520
# training accuracy: 0.341245
# validation accuracy: 0.360000
# 52 9.504994769734786e-07 46147.92799378556
# iteration 0 / 1500: loss 1439.345442
# iteration 100 / 1500: loss 7.922891
# iteration 200 / 1500: loss 7.064817
# iteration 300 / 1500: loss 6.641570
# iteration 400 / 1500: loss 6.269620
# iteration 500 / 1500: loss 7.002073
# iteration 600 / 1500: loss 7.327837
# iteration 700 / 1500: loss 6.493343
# iteration 800 / 1500: loss 7.301039
# iteration 900 / 1500: loss 7.610852
# iteration 1000 / 1500: loss 7.269860
# iteration 1100 / 1500: loss 7.347047
# iteration 1200 / 1500: loss 8.813898
# iteration 1300 / 1500: loss 6.841512
# iteration 1400 / 1500: loss 6.037252
# training accuracy: 0.266388
# validation accuracy: 0.359000
# 53 2.075319570584904e-07 47079.306737723295
# iteration 0 / 1500: loss 1468.483759
# iteration 100 / 1500: loss 33.166667
# iteration 200 / 1500: loss 6.065898
# iteration 300 / 1500: loss 5.796529
# iteration 400 / 1500: loss 5.920054
# iteration 500 / 1500: loss 6.053641
# iteration 600 / 1500: loss 6.079162
# iteration 700 / 1500: loss 5.476226
# iteration 800 / 1500: loss 6.080420
# iteration 900 / 1500: loss 5.370950
# iteration 1000 / 1500: loss 5.250901
# iteration 1100 / 1500: loss 5.570020
# iteration 1200 / 1500: loss 5.503760
# iteration 1300 / 1500: loss 5.589062
# iteration 1400 / 1500: loss 6.072854
# training accuracy: 0.350878
# validation accuracy: 0.267000
# 54 4.786547340026602e-07 53896.77231053267
# iteration 0 / 1500: loss 1683.260365
# iteration 100 / 1500: loss 5.827046
# iteration 200 / 1500: loss 5.416804
# iteration 300 / 1500: loss 5.966030
# iteration 400 / 1500: loss 6.083712
# iteration 500 / 1500: loss 6.216222
# iteration 600 / 1500: loss 5.647633
# iteration 700 / 1500: loss 5.954379
# iteration 800 / 1500: loss 6.671188
# iteration 900 / 1500: loss 6.181279
# iteration 1000 / 1500: loss 5.430988
# iteration 1100 / 1500: loss 6.777085
# iteration 1200 / 1500: loss 5.590049
# iteration 1300 / 1500: loss 6.034063
# iteration 1400 / 1500: loss 5.997023
# training accuracy: 0.321286
# validation accuracy: 0.366000
# 55 6.390055187277286e-07 21587.662610997766
# iteration 0 / 1500: loss 686.730682
# iteration 100 / 1500: loss 7.761084
# iteration 200 / 1500: loss 5.903872
# iteration 300 / 1500: loss 6.259400
# iteration 400 / 1500: loss 6.019234
# iteration 500 / 1500: loss 5.438761
# iteration 600 / 1500: loss 5.551121
# iteration 700 / 1500: loss 5.589725
# iteration 800 / 1500: loss 5.603508
# iteration 900 / 1500: loss 6.565017
# iteration 1000 / 1500: loss 5.703539
# iteration 1100 / 1500: loss 5.748564
# iteration 1200 / 1500: loss 5.670897
# iteration 1300 / 1500: loss 6.046538
# iteration 1400 / 1500: loss 5.522844
# training accuracy: 0.322612
# validation accuracy: 0.345000
# 56 5.300299781260484e-07 45154.894129515815
# iteration 0 / 1500: loss 1416.452289
# iteration 100 / 1500: loss 5.509103
# iteration 200 / 1500: loss 5.974090
# iteration 300 / 1500: loss 6.116471
# iteration 400 / 1500: loss 5.758108
# iteration 500 / 1500: loss 6.039623
# iteration 600 / 1500: loss 5.766781
# iteration 700 / 1500: loss 5.595984
# iteration 800 / 1500: loss 6.262325
# iteration 900 / 1500: loss 5.781034
# iteration 1000 / 1500: loss 6.052821
# iteration 1100 / 1500: loss 6.056536
# iteration 1200 / 1500: loss 6.208025
# iteration 1300 / 1500: loss 6.562937
# iteration 1400 / 1500: loss 6.235864
# training accuracy: 0.325980
# validation accuracy: 0.342000
# 57 5.131118458027868e-07 37168.183740846915
# iteration 0 / 1500: loss 1165.411261
# iteration 100 / 1500: loss 6.704873
# iteration 200 / 1500: loss 6.407321
# iteration 300 / 1500: loss 5.573495
# iteration 400 / 1500: loss 5.656055
# iteration 500 / 1500: loss 6.557327
# iteration 600 / 1500: loss 5.565395
# iteration 700 / 1500: loss 5.432253
# iteration 800 / 1500: loss 5.680267
# iteration 900 / 1500: loss 5.981268
# iteration 1000 / 1500: loss 5.883814
# iteration 1100 / 1500: loss 6.131964
# iteration 1200 / 1500: loss 5.642915
# iteration 1300 / 1500: loss 5.694396
# iteration 1400 / 1500: loss 5.738266
# training accuracy: 0.324388
# validation accuracy: 0.338000
# 58 1.4537214268514197e-07 50159.673340346926
# iteration 0 / 1500: loss 1552.971461
# iteration 100 / 1500: loss 85.804406
# iteration 200 / 1500: loss 9.930140
# iteration 300 / 1500: loss 6.135690
# iteration 400 / 1500: loss 5.550055
# iteration 500 / 1500: loss 5.321368
# iteration 600 / 1500: loss 5.692918
# iteration 700 / 1500: loss 5.741560
# iteration 800 / 1500: loss 5.816769
# iteration 900 / 1500: loss 5.817184
# iteration 1000 / 1500: loss 5.814266
# iteration 1100 / 1500: loss 5.450890
# iteration 1200 / 1500: loss 5.747615
# iteration 1300 / 1500: loss 5.704313
# iteration 1400 / 1500: loss 5.840299
# training accuracy: 0.362735
# validation accuracy: 0.347000
# 59 4.463770679934162e-07 27326.042812568354
# iteration 0 / 1500: loss 853.622981
# iteration 100 / 1500: loss 11.154090
# iteration 200 / 1500: loss 6.019224
# iteration 300 / 1500: loss 5.952882
# iteration 400 / 1500: loss 5.706057
# iteration 500 / 1500: loss 4.898784
# iteration 600 / 1500: loss 5.765920
# iteration 700 / 1500: loss 5.428789
# iteration 800 / 1500: loss 5.440833
# iteration 900 / 1500: loss 5.966012
# iteration 1000 / 1500: loss 6.551961
# iteration 1100 / 1500: loss 5.838692
# iteration 1200 / 1500: loss 5.626408
# iteration 1300 / 1500: loss 5.625970
# iteration 1400 / 1500: loss 6.105386
# training accuracy: 0.333816
# validation accuracy: 0.381000
# 60 4.7595562349810645e-07 44750.178630293136
# iteration 0 / 1500: loss 1382.257407
# iteration 100 / 1500: loss 5.713595
# iteration 200 / 1500: loss 6.431248
# iteration 300 / 1500: loss 6.200328
# iteration 400 / 1500: loss 5.337939
# iteration 500 / 1500: loss 5.877727
# iteration 600 / 1500: loss 5.754485
# iteration 700 / 1500: loss 6.137478
# iteration 800 / 1500: loss 6.044774
# iteration 900 / 1500: loss 6.246303
# iteration 1000 / 1500: loss 6.154786
# iteration 1100 / 1500: loss 6.028985
# iteration 1200 / 1500: loss 6.538700
# iteration 1300 / 1500: loss 5.914759
# iteration 1400 / 1500: loss 5.287104
# training accuracy: 0.299041
# validation accuracy: 0.347000
# 61 7.009488696079683e-07 33392.462880074265
# iteration 0 / 1500: loss 1044.567559
# iteration 100 / 1500: loss 7.496920
# iteration 200 / 1500: loss 5.711342
# iteration 300 / 1500: loss 6.284792
# iteration 400 / 1500: loss 6.295409
# iteration 500 / 1500: loss 6.114762
# iteration 600 / 1500: loss 6.126356
# iteration 700 / 1500: loss 5.771286
# iteration 800 / 1500: loss 5.868076
# iteration 900 / 1500: loss 6.001486
# iteration 1000 / 1500: loss 6.927964
# iteration 1100 / 1500: loss 5.485816
# iteration 1200 / 1500: loss 6.266053
# iteration 1300 / 1500: loss 6.030414
# iteration 1400 / 1500: loss 6.946958
# training accuracy: 0.327673
# validation accuracy: 0.303000
# 62 8.969774213220057e-07 52459.08296136354
# iteration 0 / 1500: loss 1644.295525
# iteration 100 / 1500: loss 6.669732
# iteration 200 / 1500: loss 7.384807
# iteration 300 / 1500: loss 6.987555
# iteration 400 / 1500: loss 6.730581
# iteration 500 / 1500: loss 6.766658
# iteration 600 / 1500: loss 7.152731
# iteration 700 / 1500: loss 6.915737
# iteration 800 / 1500: loss 6.831606
# iteration 900 / 1500: loss 5.649705
# iteration 1000 / 1500: loss 7.097374
# iteration 1100 / 1500: loss 6.829632
# iteration 1200 / 1500: loss 6.804915
# iteration 1300 / 1500: loss 7.232103
# iteration 1400 / 1500: loss 7.376316
# training accuracy: 0.252000
# validation accuracy: 0.328000
# 63 7.629997917691618e-07 58893.52394989259
# iteration 0 / 1500: loss 1830.643170
# iteration 100 / 1500: loss 6.653647
# iteration 200 / 1500: loss 6.578147
# iteration 300 / 1500: loss 6.726684
# iteration 400 / 1500: loss 6.516730
# iteration 500 / 1500: loss 6.524920
# iteration 600 / 1500: loss 7.367155
# iteration 700 / 1500: loss 7.209297
# iteration 800 / 1500: loss 6.699900
# iteration 900 / 1500: loss 6.935688
# iteration 1000 / 1500: loss 6.852706
# iteration 1100 / 1500: loss 7.966600
# iteration 1200 / 1500: loss 7.519624
# iteration 1300 / 1500: loss 6.511567
# iteration 1400 / 1500: loss 7.117666
# training accuracy: 0.277367
# validation accuracy: 0.270000
# 64 8.065980530365068e-07 33660.15893946959
# iteration 0 / 1500: loss 1047.370846
# iteration 100 / 1500: loss 6.202211
# iteration 200 / 1500: loss 6.310008
# iteration 300 / 1500: loss 7.329357
# iteration 400 / 1500: loss 6.355027
# iteration 500 / 1500: loss 6.281444
# iteration 600 / 1500: loss 6.199655
# iteration 700 / 1500: loss 5.823231
# iteration 800 / 1500: loss 6.982541
# iteration 900 / 1500: loss 7.605852
# iteration 1000 / 1500: loss 6.180892
# iteration 1100 / 1500: loss 6.706181
# iteration 1200 / 1500: loss 6.785866
# iteration 1300 / 1500: loss 6.156060
# iteration 1400 / 1500: loss 6.432650
# training accuracy: 0.271510
# validation accuracy: 0.301000
# 65 4.5280485023659414e-07 55640.75100528726
# iteration 0 / 1500: loss 1740.434407
# iteration 100 / 1500: loss 6.469822
# iteration 200 / 1500: loss 6.377523
# iteration 300 / 1500: loss 6.015854
# iteration 400 / 1500: loss 6.279687
# iteration 500 / 1500: loss 5.580180
# iteration 600 / 1500: loss 6.622283
# iteration 700 / 1500: loss 5.794899
# iteration 800 / 1500: loss 5.777284
# iteration 900 / 1500: loss 5.988107
# iteration 1000 / 1500: loss 6.343498
# iteration 1100 / 1500: loss 5.566007
# iteration 1200 / 1500: loss 5.512633
# iteration 1300 / 1500: loss 6.158932
# iteration 1400 / 1500: loss 6.058231
# training accuracy: 0.318510
# validation accuracy: 0.265000
# 66 8.783781102642456e-07 22366.291369179216
# iteration 0 / 1500: loss 708.114599
# iteration 100 / 1500: loss 6.313685
# iteration 200 / 1500: loss 5.452639
# iteration 300 / 1500: loss 6.681479
# iteration 400 / 1500: loss 6.694451
# iteration 500 / 1500: loss 6.889441
# iteration 600 / 1500: loss 6.231799
# iteration 700 / 1500: loss 5.828594
# iteration 800 / 1500: loss 6.046673
# iteration 900 / 1500: loss 6.511983
# iteration 1000 / 1500: loss 6.476854
# iteration 1100 / 1500: loss 6.872069
# iteration 1200 / 1500: loss 6.621143
# iteration 1300 / 1500: loss 6.644779
# iteration 1400 / 1500: loss 5.841327
# training accuracy: 0.322816
# validation accuracy: 0.336000
# 67 2.0259765071905752e-07 55288.68788693064
# iteration 0 / 1500: loss 1691.431808
# iteration 100 / 1500: loss 23.608662
# iteration 200 / 1500: loss 6.462498
# iteration 300 / 1500: loss 5.871718
# iteration 400 / 1500: loss 5.845314
# iteration 500 / 1500: loss 5.914675
# iteration 600 / 1500: loss 5.924149
# iteration 700 / 1500: loss 6.129009
# iteration 800 / 1500: loss 6.026247
# iteration 900 / 1500: loss 5.428416
# iteration 1000 / 1500: loss 5.708653
# iteration 1100 / 1500: loss 5.445919
# iteration 1200 / 1500: loss 5.933616
# iteration 1300 / 1500: loss 6.358021
# iteration 1400 / 1500: loss 5.842878
# training accuracy: 0.361857
# validation accuracy: 0.324000
# 68 7.760489530285761e-07 33075.834990339215
# iteration 0 / 1500: loss 1023.621349
# iteration 100 / 1500: loss 5.508912
# iteration 200 / 1500: loss 7.354879
# iteration 300 / 1500: loss 5.550256
# iteration 400 / 1500: loss 6.866291
# iteration 500 / 1500: loss 6.088036
# iteration 600 / 1500: loss 6.490176
# iteration 700 / 1500: loss 6.295067
# iteration 800 / 1500: loss 5.370058
# iteration 900 / 1500: loss 6.859371
# iteration 1000 / 1500: loss 5.921954
# iteration 1100 / 1500: loss 6.707898
# iteration 1200 / 1500: loss 5.616568
# iteration 1300 / 1500: loss 6.024911
# iteration 1400 / 1500: loss 6.392828
# training accuracy: 0.276612
# validation accuracy: 0.369000
# 69 3.73367773440082e-07 34838.48076554558
# iteration 0 / 1500: loss 1110.714436
# iteration 100 / 1500: loss 10.925943
# iteration 200 / 1500: loss 5.857218
# iteration 300 / 1500: loss 6.386491
# iteration 400 / 1500: loss 5.669962
# iteration 500 / 1500: loss 6.218259
# iteration 600 / 1500: loss 5.736929
# iteration 700 / 1500: loss 5.760107
# iteration 800 / 1500: loss 5.742260
# iteration 900 / 1500: loss 6.189547
# iteration 1000 / 1500: loss 5.063722
# iteration 1100 / 1500: loss 5.853970
# iteration 1200 / 1500: loss 5.887814
# iteration 1300 / 1500: loss 5.531968
# iteration 1400 / 1500: loss 5.526922
# training accuracy: 0.344653
# validation accuracy: 0.301000
# 70 5.275595272842023e-07 32782.42779255616
# iteration 0 / 1500: loss 1027.847461
# iteration 100 / 1500: loss 7.515011
# iteration 200 / 1500: loss 5.575416
# iteration 300 / 1500: loss 5.895261
# iteration 400 / 1500: loss 6.268122
# iteration 500 / 1500: loss 6.392873
# iteration 600 / 1500: loss 6.316313
# iteration 700 / 1500: loss 6.292756
# iteration 800 / 1500: loss 5.643182
# iteration 900 / 1500: loss 5.864715
# iteration 1000 / 1500: loss 6.296096
# iteration 1100 / 1500: loss 6.157455
# iteration 1200 / 1500: loss 5.743839
# iteration 1300 / 1500: loss 5.924825
# iteration 1400 / 1500: loss 5.821715
# training accuracy: 0.321000
# validation accuracy: 0.352000
# 71 3.6603047030673844e-07 48114.22436381534
# iteration 0 / 1500: loss 1495.029380
# iteration 100 / 1500: loss 6.723700
# iteration 200 / 1500: loss 5.757497
# iteration 300 / 1500: loss 6.290241
# iteration 400 / 1500: loss 5.536908
# iteration 500 / 1500: loss 6.232141
# iteration 600 / 1500: loss 6.188016
# iteration 700 / 1500: loss 5.774951
# iteration 800 / 1500: loss 5.460913
# iteration 900 / 1500: loss 6.095840
# iteration 1000 / 1500: loss 6.263092
# iteration 1100 / 1500: loss 6.009476
# iteration 1200 / 1500: loss 5.938157
# iteration 1300 / 1500: loss 6.184793
# iteration 1400 / 1500: loss 5.435237
# training accuracy: 0.312245
# validation accuracy: 0.322000
# 72 1.2832201867727012e-07 23424.95334092946
# iteration 0 / 1500: loss 745.990940
# iteration 100 / 1500: loss 221.455721
# iteration 200 / 1500: loss 68.715500
# iteration 300 / 1500: loss 24.833278
# iteration 400 / 1500: loss 10.659708
# iteration 500 / 1500: loss 7.212223
# iteration 600 / 1500: loss 5.314588
# iteration 700 / 1500: loss 5.098942
# iteration 800 / 1500: loss 5.071387
# iteration 900 / 1500: loss 4.964347
# iteration 1000 / 1500: loss 5.220406
# iteration 1100 / 1500: loss 5.092747
# iteration 1200 / 1500: loss 5.194965
# iteration 1300 / 1500: loss 4.937607
# iteration 1400 / 1500: loss 4.853342
# training accuracy: 0.365020
# validation accuracy: 0.323000
# 73 8.266454122011533e-07 32190.714870216998
# iteration 0 / 1500: loss 1009.541168
# iteration 100 / 1500: loss 7.915169
# iteration 200 / 1500: loss 7.402176
# iteration 300 / 1500: loss 5.773345
# iteration 400 / 1500: loss 6.617520
# iteration 500 / 1500: loss 6.818714
# iteration 600 / 1500: loss 6.755746
# iteration 700 / 1500: loss 6.738408
# iteration 800 / 1500: loss 5.976728
# iteration 900 / 1500: loss 6.854202
# iteration 1000 / 1500: loss 6.265511
# iteration 1100 / 1500: loss 6.242853
# iteration 1200 / 1500: loss 5.742354
# iteration 1300 / 1500: loss 6.581862
# iteration 1400 / 1500: loss 7.333279
# training accuracy: 0.297184
# validation accuracy: 0.367000
# 74 9.113097286215575e-07 52242.19069505547
# ...
# validation accuracy: 0.291000
# 88 2.1873510120085227e-07 20604.44916424518
# iteration 0 / 1500: loss 645.035783
# iteration 100 / 1500: loss 106.847183
# iteration 200 / 1500: loss 21.369868
# iteration 300 / 1500: loss 8.003746
# iteration 400 / 1500: loss 5.867689
# iteration 500 / 1500: loss 5.566767
# iteration 600 / 1500: loss 5.383331
# iteration 700 / 1500: loss 5.382632
# iteration 800 / 1500: loss 5.073943
# iteration 900 / 1500: loss 5.462505
# iteration 1000 / 1500: loss 5.332588
# iteration 1100 / 1500: loss 5.328965
# iteration 1200 / 1500: loss 5.393480
# iteration 1300 / 1500: loss 5.692382
# iteration 1400 / 1500: loss 5.518353
# training accuracy: 0.366694
# validation accuracy: 0.335000
# 89 2.0398369235475267e-07 31628.290451841465
# iteration 0 / 1500: loss 1005.459483
# iteration 100 / 1500: loss 78.587772
# iteration 200 / 1500: loss 10.786692
# iteration 300 / 1500: loss 5.694639
# iteration 400 / 1500: loss 5.403517
# iteration 500 / 1500: loss 5.661960
# iteration 600 / 1500: loss 5.447444
# iteration 700 / 1500: loss 5.457246
# iteration 800 / 1500: loss 5.057912
# iteration 900 / 1500: loss 5.548127
# iteration 1000 / 1500: loss 5.190523
# iteration 1100 / 1500: loss 5.547336
# iteration 1200 / 1500: loss 5.366589
# iteration 1300 / 1500: loss 5.413178
# iteration 1400 / 1500: loss 5.048943
# training accuracy: 0.351980
# validation accuracy: 0.373000
# 90 9.226913149007115e-07 35902.811288153665
# iteration 0 / 1500: loss 1109.629962
# iteration 100 / 1500: loss 6.532091
# iteration 200 / 1500: loss 7.446367
# iteration 300 / 1500: loss 6.499746
# iteration 400 / 1500: loss 7.416485
# iteration 500 / 1500: loss 8.043903
# iteration 600 / 1500: loss 6.310841
# iteration 700 / 1500: loss 7.619616
# iteration 800 / 1500: loss 5.858520
# iteration 900 / 1500: loss 7.351596
# iteration 1000 / 1500: loss 6.780936
# iteration 1100 / 1500: loss 7.836906
# iteration 1200 / 1500: loss 5.880211
# iteration 1300 / 1500: loss 7.475109
# iteration 1400 / 1500: loss 6.284839
# training accuracy: 0.299265
# validation accuracy: 0.357000
# 91 1.507657881418885e-07 38623.81938966683
# iteration 0 / 1500: loss 1218.224638
# iteration 100 / 1500: loss 119.131860
# iteration 200 / 1500: loss 16.054287
# iteration 300 / 1500: loss 7.177720
# iteration 400 / 1500: loss 5.176960
# iteration 500 / 1500: loss 5.516530
# iteration 600 / 1500: loss 5.713552
# iteration 700 / 1500: loss 5.376741
# iteration 800 / 1500: loss 5.746548
# iteration 900 / 1500: loss 5.860382
# iteration 1000 / 1500: loss 5.688403
# iteration 1100 / 1500: loss 5.271493
# iteration 1200 / 1500: loss 5.779214
# iteration 1300 / 1500: loss 5.362259
# iteration 1400 / 1500: loss 5.277089
# training accuracy: 0.358041
# validation accuracy: 0.318000
# 92 8.351559599593595e-07 41866.237380692364
# iteration 0 / 1500: loss 1307.044007
# iteration 100 / 1500: loss 6.705875
# iteration 200 / 1500: loss 6.629663
# iteration 300 / 1500: loss 7.061224
# iteration 400 / 1500: loss 6.283878
# iteration 500 / 1500: loss 6.291695
# iteration 600 / 1500: loss 7.023473
# iteration 700 / 1500: loss 6.495510
# iteration 800 / 1500: loss 6.551187
# iteration 900 / 1500: loss 6.250463
# iteration 1000 / 1500: loss 6.738703
# iteration 1100 / 1500: loss 6.828848
# iteration 1200 / 1500: loss 7.502911
# iteration 1300 / 1500: loss 6.728021
# iteration 1400 / 1500: loss 6.383493
# training accuracy: 0.290755
# validation accuracy: 0.381000
# 93 9.7231615029899e-07 30043.370875193315
# iteration 0 / 1500: loss 954.157622
# iteration 100 / 1500: loss 6.381905
# iteration 200 / 1500: loss 7.062256
# iteration 300 / 1500: loss 6.268582
# iteration 400 / 1500: loss 6.934960
# iteration 500 / 1500: loss 7.484189
# iteration 600 / 1500: loss 6.214797
# iteration 700 / 1500: loss 7.041116
# iteration 800 / 1500: loss 7.444763
# iteration 900 / 1500: loss 6.622657
# iteration 1000 / 1500: loss 6.610379
# iteration 1100 / 1500: loss 7.125153
# iteration 1200 / 1500: loss 7.270608
# iteration 1300 / 1500: loss 6.278537
# iteration 1400 / 1500: loss 8.659897
# training accuracy: 0.280980
# validation accuracy: 0.268000
# 94 5.276992782055611e-07 56460.91502167213
# iteration 0 / 1500: loss 1748.827895
# iteration 100 / 1500: loss 6.686391
# iteration 200 / 1500: loss 6.012766
# iteration 300 / 1500: loss 6.055683
# iteration 400 / 1500: loss 6.197400
# iteration 500 / 1500: loss 5.918933
# iteration 600 / 1500: loss 6.378780
# iteration 700 / 1500: loss 6.487470
# iteration 800 / 1500: loss 5.855923
# iteration 900 / 1500: loss 6.419863
# iteration 1000 / 1500: loss 6.127622
# iteration 1100 / 1500: loss 6.264196
# iteration 1200 / 1500: loss 6.215266
# iteration 1300 / 1500: loss 6.654626
# iteration 1400 / 1500: loss 6.166336
# training accuracy: 0.287959
# validation accuracy: 0.277000
# 95 1.0715979245410617e-07 58293.030409978994
# iteration 0 / 1500: loss 1810.788567
# iteration 100 / 1500: loss 150.259839
# iteration 200 / 1500: loss 17.436488
# iteration 300 / 1500: loss 6.678875
# iteration 400 / 1500: loss 6.200656
# iteration 500 / 1500: loss 5.576515
# iteration 600 / 1500: loss 5.884725
# iteration 700 / 1500: loss 5.954742
# iteration 800 / 1500: loss 5.829739
# iteration 900 / 1500: loss 5.814100
# iteration 1000 / 1500: loss 5.519198
# iteration 1100 / 1500: loss 5.859506
# iteration 1200 / 1500: loss 5.564825
# iteration 1300 / 1500: loss 5.909376
# iteration 1400 / 1500: loss 6.176939
# training accuracy: 0.352837
# validation accuracy: 0.304000
# 96 9.21157700397433e-07 36171.02181644099
# iteration 0 / 1500: loss 1139.046656
# iteration 100 / 1500: loss 7.731389
# iteration 200 / 1500: loss 7.070429
# iteration 300 / 1500: loss 6.564926
# iteration 400 / 1500: loss 7.413810
# iteration 500 / 1500: loss 8.102416
# iteration 600 / 1500: loss 6.274470
# iteration 700 / 1500: loss 6.602285
# iteration 800 / 1500: loss 7.856025
# iteration 900 / 1500: loss 8.102690
# iteration 1000 / 1500: loss 6.789056
# iteration 1100 / 1500: loss 6.345155
# iteration 1200 / 1500: loss 6.920688
# iteration 1300 / 1500: loss 6.831780
# iteration 1400 / 1500: loss 6.592910
# training accuracy: 0.271163
# validation accuracy: 0.364000
# 97 8.450656776055998e-07 26548.178984336548
# iteration 0 / 1500: loss 832.874456
# iteration 100 / 1500: loss 5.937161
# iteration 200 / 1500: loss 5.879336
# iteration 300 / 1500: loss 6.568651
# iteration 400 / 1500: loss 6.711021
# iteration 500 / 1500: loss 6.639360
# iteration 600 / 1500: loss 7.375163
# iteration 700 / 1500: loss 5.825491
# iteration 800 / 1500: loss 5.969560
# iteration 900 / 1500: loss 6.982160
# iteration 1000 / 1500: loss 6.264053
# iteration 1100 / 1500: loss 6.659801
# iteration 1200 / 1500: loss 5.950315
# iteration 1300 / 1500: loss 5.940568
# iteration 1400 / 1500: loss 6.937243
# training accuracy: 0.305918
# validation accuracy: 0.286000
# 98 8.889668902095988e-07 40030.398466991515
# iteration 0 / 1500: loss 1246.826164
# iteration 100 / 1500: loss 8.083162
# iteration 200 / 1500: loss 6.550759
# iteration 300 / 1500: loss 6.861705
# iteration 400 / 1500: loss 6.529515
# iteration 500 / 1500: loss 6.783857
# iteration 600 / 1500: loss 5.934662
# iteration 700 / 1500: loss 6.527688
# iteration 800 / 1500: loss 7.399476
# iteration 900 / 1500: loss 7.345296
# iteration 1000 / 1500: loss 7.175788
# iteration 1100 / 1500: loss 7.651146
# iteration 1200 / 1500: loss 7.480347
# iteration 1300 / 1500: loss 7.542174
# iteration 1400 / 1500: loss 6.779882
# training accuracy: 0.284490
# validation accuracy: 0.303000
# 99 8.381771762067985e-07 38629.95439318409
# iteration 0 / 1500: loss 1227.606755
# iteration 100 / 1500: loss 6.446846
# iteration 200 / 1500: loss 7.239687
# iteration 300 / 1500: loss 6.254158
# iteration 400 / 1500: loss 6.787618
# iteration 500 / 1500: loss 6.702607
# iteration 600 / 1500: loss 6.535373
# iteration 700 / 1500: loss 6.643536
# iteration 800 / 1500: loss 6.157038
# iteration 900 / 1500: loss 6.655686
# iteration 1000 / 1500: loss 7.250574
# iteration 1100 / 1500: loss 6.380114
# iteration 1200 / 1500: loss 7.547772
# iteration 1300 / 1500: loss 6.806706
# iteration 1400 / 1500: loss 6.407133
# training accuracy: 0.304102
# validation accuracy: 0.280000
# lr 1.071598e-07 reg 5.829303e+04 train accuracy: 0.352837 val accuracy: 0.304000
# lr 1.075710e-07 reg 2.149945e+04 train accuracy: 0.369959 val accuracy: 0.315000
# lr 1.243010e-07 reg 3.036585e+04 train accuracy: 0.363184 val accuracy: 0.374000
# lr 1.283220e-07 reg 2.342495e+04 train accuracy: 0.365020 val accuracy: 0.323000
# lr 1.344070e-07 reg 4.096120e+04 train accuracy: 0.359755 val accuracy: 0.275000
# lr 1.449222e-07 reg 4.973883e+04 train accuracy: 0.362286 val accuracy: 0.355000
# lr 1.453721e-07 reg 5.015967e+04 train accuracy: 0.362735 val accuracy: 0.347000
# lr 1.507658e-07 reg 3.862382e+04 train accuracy: 0.358041 val accuracy: 0.318000
# lr 1.547693e-07 reg 5.809411e+04 train accuracy: 0.351367 val accuracy: 0.261000
# lr 1.581732e-07 reg 2.004512e+04 train accuracy: 0.367878 val accuracy: 0.375000
# lr 1.640764e-07 reg 2.525686e+04 train accuracy: 0.369327 val accuracy: 0.307000
# lr 2.025977e-07 reg 5.528869e+04 train accuracy: 0.361857 val accuracy: 0.324000
# lr 2.039837e-07 reg 3.162829e+04 train accuracy: 0.351980 val accuracy: 0.373000
# lr 2.075320e-07 reg 4.707931e+04 train accuracy: 0.350878 val accuracy: 0.267000
# lr 2.187351e-07 reg 2.060445e+04 train accuracy: 0.366694 val accuracy: 0.335000
# lr 2.187919e-07 reg 3.591119e+04 train accuracy: 0.361980 val accuracy: 0.289000
# lr 2.199627e-07 reg 3.480352e+04 train accuracy: 0.358265 val accuracy: 0.312000
# lr 2.303014e-07 reg 5.684027e+04 train accuracy: 0.346449 val accuracy: 0.303000
# lr 2.341182e-07 reg 5.098956e+04 train accuracy: 0.348082 val accuracy: 0.389000
# lr 2.401917e-07 reg 3.750824e+04 train accuracy: 0.349878 val accuracy: 0.326000
# lr 2.587469e-07 reg 5.652102e+04 train accuracy: 0.330102 val accuracy: 0.281000
# lr 2.670296e-07 reg 4.193238e+04 train accuracy: 0.344837 val accuracy: 0.355000
# lr 3.033942e-07 reg 4.922525e+04 train accuracy: 0.340388 val accuracy: 0.283000
# lr 3.280916e-07 reg 2.764842e+04 train accuracy: 0.350837 val accuracy: 0.330000
# lr 3.598068e-07 reg 4.853069e+04 train accuracy: 0.331204 val accuracy: 0.331000
# lr 3.660305e-07 reg 4.811422e+04 train accuracy: 0.312245 val accuracy: 0.322000
# lr 3.672987e-07 reg 5.227190e+04 train accuracy: 0.342755 val accuracy: 0.340000
# lr 3.699831e-07 reg 3.765170e+04 train accuracy: 0.329592 val accuracy: 0.307000
# lr 3.733678e-07 reg 3.483848e+04 train accuracy: 0.344653 val accuracy: 0.301000
# lr 3.879029e-07 reg 5.409317e+04 train accuracy: 0.336796 val accuracy: 0.283000
# lr 3.887478e-07 reg 3.448729e+04 train accuracy: 0.343388 val accuracy: 0.372000
# lr 3.892082e-07 reg 3.956452e+04 train accuracy: 0.334020 val accuracy: 0.331000
# lr 3.992805e-07 reg 3.137379e+04 train accuracy: 0.343837 val accuracy: 0.283000
# lr 4.120331e-07 reg 5.644533e+04 train accuracy: 0.322857 val accuracy: 0.376000
# lr 4.139535e-07 reg 4.624824e+04 train accuracy: 0.329286 val accuracy: 0.355000
# lr 4.243017e-07 reg 5.224056e+04 train accuracy: 0.344327 val accuracy: 0.361000
# lr 4.346837e-07 reg 3.027585e+04 train accuracy: 0.321959 val accuracy: 0.358000
# lr 4.463771e-07 reg 2.732604e+04 train accuracy: 0.333816 val accuracy: 0.381000
# lr 4.528049e-07 reg 5.564075e+04 train accuracy: 0.318510 val accuracy: 0.265000
# lr 4.699811e-07 reg 5.495605e+04 train accuracy: 0.315000 val accuracy: 0.357000
# lr 4.759556e-07 reg 4.475018e+04 train accuracy: 0.299041 val accuracy: 0.347000
# lr 4.786140e-07 reg 5.185338e+04 train accuracy: 0.333306 val accuracy: 0.326000
# lr 4.786547e-07 reg 5.389677e+04 train accuracy: 0.321286 val accuracy: 0.366000
# lr 4.878856e-07 reg 5.018546e+04 train accuracy: 0.319551 val accuracy: 0.305000
# lr 4.899156e-07 reg 3.251066e+04 train accuracy: 0.318878 val accuracy: 0.291000
# lr 5.114026e-07 reg 4.313470e+04 train accuracy: 0.335388 val accuracy: 0.314000
# lr 5.131118e-07 reg 3.716818e+04 train accuracy: 0.324388 val accuracy: 0.338000
# lr 5.146184e-07 reg 3.906901e+04 train accuracy: 0.326469 val accuracy: 0.329000
# lr 5.275595e-07 reg 3.278243e+04 train accuracy: 0.321000 val accuracy: 0.352000
# lr 5.276993e-07 reg 5.646092e+04 train accuracy: 0.287959 val accuracy: 0.277000
# lr 5.300300e-07 reg 4.515489e+04 train accuracy: 0.325980 val accuracy: 0.342000
# lr 5.439973e-07 reg 5.057421e+04 train accuracy: 0.300020 val accuracy: 0.283000
# lr 5.837620e-07 reg 4.806609e+04 train accuracy: 0.271490 val accuracy: 0.339000
# lr 5.937147e-07 reg 2.022807e+04 train accuracy: 0.336306 val accuracy: 0.337000
# lr 6.038484e-07 reg 2.773064e+04 train accuracy: 0.300816 val accuracy: 0.353000
# lr 6.271834e-07 reg 3.884934e+04 train accuracy: 0.341245 val accuracy: 0.360000
# lr 6.322059e-07 reg 2.960810e+04 train accuracy: 0.311102 val accuracy: 0.283000
# lr 6.390055e-07 reg 2.158766e+04 train accuracy: 0.322612 val accuracy: 0.345000
# lr 6.441250e-07 reg 3.901534e+04 train accuracy: 0.307347 val accuracy: 0.372000
# lr 6.539730e-07 reg 5.432612e+04 train accuracy: 0.294061 val accuracy: 0.361000
# lr 6.682413e-07 reg 4.132995e+04 train accuracy: 0.300551 val accuracy: 0.306000
# lr 6.944786e-07 reg 5.343468e+04 train accuracy: 0.289408 val accuracy: 0.351000
# lr 6.975072e-07 reg 3.426731e+04 train accuracy: 0.335653 val accuracy: 0.364000
# lr 7.009489e-07 reg 3.339246e+04 train accuracy: 0.327673 val accuracy: 0.303000
# lr 7.133140e-07 reg 5.361634e+04 train accuracy: 0.285592 val accuracy: 0.350000
# lr 7.330136e-07 reg 2.886839e+04 train accuracy: 0.279816 val accuracy: 0.291000
# lr 7.535055e-07 reg 5.333626e+04 train accuracy: 0.270735 val accuracy: 0.361000
# lr 7.536128e-07 reg 5.146802e+04 train accuracy: 0.307122 val accuracy: 0.376000
# lr 7.629998e-07 reg 5.889352e+04 train accuracy: 0.277367 val accuracy: 0.270000
# lr 7.760490e-07 reg 3.307583e+04 train accuracy: 0.276612 val accuracy: 0.369000
# lr 7.880719e-07 reg 2.796145e+04 train accuracy: 0.311673 val accuracy: 0.276000
# lr 8.041959e-07 reg 3.762415e+04 train accuracy: 0.302612 val accuracy: 0.333000
# lr 8.065981e-07 reg 3.366016e+04 train accuracy: 0.271510 val accuracy: 0.301000
# lr 8.266454e-07 reg 3.219071e+04 train accuracy: 0.297184 val accuracy: 0.367000
# lr 8.303784e-07 reg 5.478239e+04 train accuracy: 0.283714 val accuracy: 0.356000
# lr 8.343976e-07 reg 2.659039e+04 train accuracy: 0.324939 val accuracy: 0.298000
# lr 8.351560e-07 reg 4.186624e+04 train accuracy: 0.290755 val accuracy: 0.381000
# lr 8.380376e-07 reg 5.032848e+04 train accuracy: 0.258286 val accuracy: 0.362000
# lr 8.381772e-07 reg 3.862995e+04 train accuracy: 0.304102 val accuracy: 0.280000
# lr 8.450657e-07 reg 2.654818e+04 train accuracy: 0.305918 val accuracy: 0.286000
# lr 8.454996e-07 reg 5.615062e+04 train accuracy: 0.278122 val accuracy: 0.322000
# lr 8.619081e-07 reg 2.877129e+04 train accuracy: 0.288571 val accuracy: 0.286000
# lr 8.713215e-07 reg 5.810278e+04 train accuracy: 0.283510 val accuracy: 0.296000
# lr 8.783781e-07 reg 2.236629e+04 train accuracy: 0.322816 val accuracy: 0.336000
# lr 8.819143e-07 reg 2.046009e+04 train accuracy: 0.318286 val accuracy: 0.357000
# lr 8.882552e-07 reg 5.523113e+04 train accuracy: 0.255245 val accuracy: 0.340000
# lr 8.889669e-07 reg 4.003040e+04 train accuracy: 0.284490 val accuracy: 0.303000
# lr 8.969774e-07 reg 5.245908e+04 train accuracy: 0.252000 val accuracy: 0.328000
# lr 9.113097e-07 reg 5.224219e+04 train accuracy: 0.256612 val accuracy: 0.313000
# lr 9.128797e-07 reg 4.068617e+04 train accuracy: 0.277592 val accuracy: 0.270000
# lr 9.211577e-07 reg 3.617102e+04 train accuracy: 0.271163 val accuracy: 0.364000
# lr 9.226913e-07 reg 3.590281e+04 train accuracy: 0.299265 val accuracy: 0.357000
# lr 9.426774e-07 reg 4.663485e+04 train accuracy: 0.283327 val accuracy: 0.351000
# lr 9.427725e-07 reg 2.907329e+04 train accuracy: 0.249388 val accuracy: 0.327000
# lr 9.442797e-07 reg 3.402635e+04 train accuracy: 0.278102 val accuracy: 0.319000
# lr 9.504995e-07 reg 4.614793e+04 train accuracy: 0.266388 val accuracy: 0.359000
# lr 9.531094e-07 reg 5.610759e+04 train accuracy: 0.287347 val accuracy: 0.247000
# lr 9.553573e-07 reg 5.989736e+04 train accuracy: 0.265224 val accuracy: 0.333000
# lr 9.723162e-07 reg 3.004337e+04 train accuracy: 0.280980 val accuracy: 0.268000
# lr 9.873690e-07 reg 4.304758e+04 train accuracy: 0.299837 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.389000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test).reshape(y_test.shape)
test_accuracy = np.mean(y_test == y_test_pred)
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.367000

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
      
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# **Inline question 2**
#
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# $\color{blue}{\textit Your Answer:}$ *We notice common shapes from images*

# %% [markdown]
# # Softmax

# %%
import numpy as np
from random import shuffle

np.set_printoptions(precision=2)
def softmax_loss_naive(W, X, y, reg):
    """
    Softmax loss function, naive implementation (with loops)

    Inputs have dimension D, there are C classes, and we operate on minibatches
    of N examples.

    Inputs:
    - W: A numpy array of shape (D, C) containing weights.
    - X: A numpy array of shape (N, D) containing a minibatch of data.
    - y: A numpy array of shape (N,) containing training labels; y[i] = c means
      that X[i] has label c, where 0 <= c < C.
    - reg: (float) regularization strength

    Returns a tuple of:
    - loss as single float
    - gradient with respect to weights W; an array of same shape as W
    """
    # Initialize the loss and gradient to zero.
    loss = 0.0
    dW = np.zeros_like(W)

    #############################################################################
    # TODO: Compute the softmax loss and its gradient using explicit loops.     #
    # Store the loss in loss and the gradient in dW. If you are not careful     #
    # here, it is easy to run into numeric instability. Don't forget the        #
    # regularization!                                                           #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    num_train = X.shape[0]
    num_classes = W.shape[1]

    for i in range(num_train):
        scores = X[i].dot(W)
        softmax = np.exp(scores)
        softmax = softmax / np.sum(softmax)
        loss += -np.log(softmax[y[i]])
        for j in range(num_classes):
            dW[:,j] += X[i] * softmax[j]
        dW[:,y[i]] -= X[i]

    loss /= num_train
    dW /= num_train
    loss += reg * np.sum(W * W)
    dW += 2 * reg * W 

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    return loss, dW


def softmax_loss_vectorized(W, X, y, reg):
    """
    Softmax loss function, vectorized version.

    Inputs and outputs are the same as softmax_loss_naive.
    """
    # Initialize the loss and gradient to zero.
    loss = 0.0
    dW = np.zeros_like(W)

    #############################################################################
    # TODO: Compute the softmax loss and its gradient using no explicit loops.  #
    # Store the loss in loss and the gradient in dW. If you are not careful     #
    # here, it is easy to run into numeric instability. Don't forget the        #
    # regularization!                                                           #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    num_train = X.shape[0]
    scores = X.dot(W)
    scores = scores - np.max(scores, axis=1, keepdims=True)
    sum_exp_scores = np.exp(scores).sum(axis=1, keepdims=True)
    softmax_matrix = np.exp(scores)/sum_exp_scores
    cci = [np.arange(num_train), y]
    loss = np.sum(-np.log(softmax_matrix[np.arange(num_train), y]) )
    softmax_matrix[cci[0], cci[1]] -= 1
    dW = X.T.dot(softmax_matrix)
    loss /= num_train
    dW /= num_train
    loss += reg * np.sum(W * W)
    dW += 2 * reg * W 

    # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    return loss, dW

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.__version__)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# 1.15.0

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    # X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
    X_train, X_test = X_train.astype(np.float64), X_test.astype(np.float64)
    y_train = y_train.reshape(-1)
    y_test = y_test.reshape(-1)

    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.356887
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Because without training we expect each class to have a probability of 10% * **bold text**

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
# from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.862055 analytic: 0.862055, relative error: 6.168091e-08
# numerical: 0.534696 analytic: 0.534696, relative error: 3.233758e-09
# numerical: 1.189816 analytic: 1.189816, relative error: 3.482604e-08
# numerical: 0.522879 analytic: 0.522879, relative error: 7.575670e-08
# numerical: -2.430810 analytic: -2.430810, relative error: 1.697123e-09
# numerical: -1.068409 analytic: -1.068409, relative error: 1.721345e-08
# numerical: 1.111633 analytic: 1.111633, relative error: 6.031232e-08
# numerical: 0.654506 analytic: 0.654506, relative error: 1.102099e-08
# numerical: -2.079749 analytic: -2.079749, relative error: 1.884830e-09
# numerical: -2.668026 analytic: -2.668026, relative error: 1.259500e-08
# numerical: 0.833492 analytic: 0.833492, relative error: 4.936492e-08
# numerical: -1.683019 analytic: -1.683019, relative error: 1.345301e-08
# numerical: -2.772704 analytic: -2.772704, relative error: 2.730735e-09
# numerical: -3.151703 analytic: -3.151704, relative error: 1.279734e-08
# numerical: -1.918729 analytic: -1.918729, relative error: 1.370529e-09
# numerical: 0.903526 analytic: 0.903526, relative error: 1.140163e-07
# numerical: -1.809230 analytic: -1.809230, relative error: 7.230972e-09
# numerical: 3.766588 analytic: 3.766588, relative error: 1.629079e-08
# numerical: 1.272422 analytic: 1.272422, relative error: 3.087388e-08
# numerical: 1.899870 analytic: 1.899869, relative error: 1.960833e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

# from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.356887e+00 computed in 0.157200s
# vectorized loss: 2.356887e+00 computed in 0.020014s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
# from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-6, 3e-6]
regularization_strengths = [.5e3, 1.5e3]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for n_iter in range(100):
    lr, rg = np.random.rand(2)
    lr = learning_rates[0] + lr * (learning_rates[1] - learning_rates[0])
    rg = regularization_strengths[0] + rg * (regularization_strengths[1] - regularization_strengths[0])
    print(n_iter, lr, rg)
    softmax = Softmax()
    softmax.train(X_train, y_train, learning_rate=lr, reg=rg,
                        num_iters=1500, verbose=True)

    y_train_pred = softmax.predict(X_train)
    y_val_pred = softmax.predict(X_val)
    train_accuracy = np.mean(y_train == y_train_pred)
    val_accuracy = np.mean(y_val == y_val_pred)
    print('training accuracy: %f' % train_accuracy )
    print('validation accuracy: %f' % val_accuracy)
    
    results[(lr,rg)] = (train_accuracy, val_accuracy)
    if best_val < val_accuracy:
        best_val = val_accuracy
        best_softmax = softmax

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 0 2.6914181872801098e-06 639.7478873082298
# iteration 0 / 1500: loss 25.473006
# iteration 100 / 1500: loss 11.804087
# iteration 200 / 1500: loss 6.695945
# iteration 300 / 1500: loss 4.152982
# iteration 400 / 1500: loss 3.059327
# iteration 500 / 1500: loss 2.367995
# iteration 600 / 1500: loss 2.160181
# iteration 700 / 1500: loss 1.962728
# iteration 800 / 1500: loss 1.882938
# iteration 900 / 1500: loss 1.844454
# iteration 1000 / 1500: loss 1.790842
# iteration 1100 / 1500: loss 1.764938
# iteration 1200 / 1500: loss 1.931133
# iteration 1300 / 1500: loss 1.785389
# iteration 1400 / 1500: loss 1.807630
# training accuracy: 0.403571
# validation accuracy: 0.401000
# 1 2.6199341938834773e-06 1055.0202487918166
# iteration 0 / 1500: loss 38.709711
# iteration 100 / 1500: loss 12.376660
# iteration 200 / 1500: loss 5.318358
# iteration 300 / 1500: loss 2.971925
# iteration 400 / 1500: loss 2.309528
# iteration 500 / 1500: loss 1.971736
# iteration 600 / 1500: loss 1.885692
# iteration 700 / 1500: loss 1.888357
# iteration 800 / 1500: loss 1.815356
# iteration 900 / 1500: loss 1.810016
# iteration 1000 / 1500: loss 1.889341
# iteration 1100 / 1500: loss 1.935507
# iteration 1200 / 1500: loss 1.803344
# iteration 1300 / 1500: loss 1.765462
# iteration 1400 / 1500: loss 1.815406
# training accuracy: 0.385184
# validation accuracy: 0.398000
# 2 2.6014699176573217e-06 667.7247137358877
# iteration 0 / 1500: loss 25.870802
# iteration 100 / 1500: loss 12.094086
# iteration 200 / 1500: loss 6.730919
# iteration 300 / 1500: loss 4.257452
# iteration 400 / 1500: loss 3.036482
# iteration 500 / 1500: loss 2.526475
# iteration 600 / 1500: loss 2.093535
# iteration 700 / 1500: loss 2.003285
# iteration 800 / 1500: loss 1.827719
# iteration 900 / 1500: loss 1.735708
# iteration 1000 / 1500: loss 1.861942
# iteration 1100 / 1500: loss 1.792574
# iteration 1200 / 1500: loss 1.847733
# iteration 1300 / 1500: loss 1.824932
# iteration 1400 / 1500: loss 1.849737
# training accuracy: 0.383898
# validation accuracy: 0.387000
# 3 2.4077507987441846e-06 584.3063356470354
# iteration 0 / 1500: loss 23.802157
# iteration 100 / 1500: loss 11.984872
# iteration 200 / 1500: loss 7.701777
# iteration 300 / 1500: loss 5.024846
# iteration 400 / 1500: loss 3.490180
# iteration 500 / 1500: loss 2.783079
# iteration 600 / 1500: loss 2.288271
# iteration 700 / 1500: loss 2.159042
# iteration 800 / 1500: loss 2.078957
# iteration 900 / 1500: loss 1.920092
# iteration 1000 / 1500: loss 1.940289
# iteration 1100 / 1500: loss 1.818656
# iteration 1200 / 1500: loss 1.920297
# iteration 1300 / 1500: loss 1.870482
# iteration 1400 / 1500: loss 1.758775
# training accuracy: 0.396612
# validation accuracy: 0.408000
# 4 1.6458508332248415e-06 1305.9756416850096
# iteration 0 / 1500: loss 46.368390
# iteration 100 / 1500: loss 18.825656
# iteration 200 / 1500: loss 8.959087
# iteration 300 / 1500: loss 4.841211
# iteration 400 / 1500: loss 3.099698
# iteration 500 / 1500: loss 2.355050
# iteration 600 / 1500: loss 2.031205
# iteration 700 / 1500: loss 1.879399
# iteration 800 / 1500: loss 1.924569
# iteration 900 / 1500: loss 1.838479
# iteration 1000 / 1500: loss 1.823431
# iteration 1100 / 1500: loss 1.925540
# iteration 1200 / 1500: loss 1.875062
# iteration 1300 / 1500: loss 1.870661
# iteration 1400 / 1500: loss 1.833981
# training accuracy: 0.389327
# validation accuracy: 0.388000
# 5 1.7617882759985376e-06 996.710274606073
# iteration 0 / 1500: loss 35.198041
# iteration 100 / 1500: loss 17.383875
# iteration 200 / 1500: loss 9.249438
# iteration 300 / 1500: loss 5.623011
# iteration 400 / 1500: loss 3.712418
# iteration 500 / 1500: loss 2.666840
# iteration 600 / 1500: loss 2.250835
# iteration 700 / 1500: loss 2.081374
# iteration 800 / 1500: loss 2.042201
# iteration 900 / 1500: loss 1.891143
# iteration 1000 / 1500: loss 1.760830
# iteration 1100 / 1500: loss 1.750103
# iteration 1200 / 1500: loss 1.824535
# iteration 1300 / 1500: loss 1.857811
# iteration 1400 / 1500: loss 1.830013
# training accuracy: 0.393102
# validation accuracy: 0.390000
# 6 1.8305611343887442e-06 1280.1895573117158
# iteration 0 / 1500: loss 44.809941
# iteration 100 / 1500: loss 17.384087
# iteration 200 / 1500: loss 7.772263
# iteration 300 / 1500: loss 4.172725
# iteration 400 / 1500: loss 2.704655
# iteration 500 / 1500: loss 2.138609
# iteration 600 / 1500: loss 2.059457
# iteration 700 / 1500: loss 1.861423
# iteration 800 / 1500: loss 2.012690
# iteration 900 / 1500: loss 1.848446
# iteration 1000 / 1500: loss 1.870496
# iteration 1100 / 1500: loss 1.810299
# iteration 1200 / 1500: loss 1.930982
# iteration 1300 / 1500: loss 1.894385
# iteration 1400 / 1500: loss 1.812130
# training accuracy: 0.387429
# validation accuracy: 0.395000
# 7 2.984242127069009e-06 1214.2956668685779
# iteration 0 / 1500: loss 43.789222
# iteration 100 / 1500: loss 10.403500
# iteration 200 / 1500: loss 3.908316
# iteration 300 / 1500: loss 2.388614
# iteration 400 / 1500: loss 2.007906
# iteration 500 / 1500: loss 1.892412
# iteration 600 / 1500: loss 1.865916
# iteration 700 / 1500: loss 1.951326
# iteration 800 / 1500: loss 1.911634
# iteration 900 / 1500: loss 1.821503
# iteration 1000 / 1500: loss 1.755795
# iteration 1100 / 1500: loss 1.902183
# iteration 1200 / 1500: loss 1.783634
# iteration 1300 / 1500: loss 1.826681
# iteration 1400 / 1500: loss 1.898629
# training accuracy: 0.374735
# validation accuracy: 0.375000
# 8 1.421064014265666e-06 629.895426048117
# iteration 0 / 1500: loss 24.178775
# iteration 100 / 1500: loss 15.901775
# iteration 200 / 1500: loss 11.243796
# iteration 300 / 1500: loss 8.212453
# iteration 400 / 1500: loss 6.331073
# iteration 500 / 1500: loss 5.018946
# iteration 600 / 1500: loss 3.846510
# iteration 700 / 1500: loss 3.280932
# iteration 800 / 1500: loss 2.846904
# iteration 900 / 1500: loss 2.433349
# iteration 1000 / 1500: loss 2.439226
# iteration 1100 / 1500: loss 2.292264
# iteration 1200 / 1500: loss 2.127319
# iteration 1300 / 1500: loss 2.029504
# iteration 1400 / 1500: loss 1.900046
# training accuracy: 0.406714
# validation accuracy: 0.401000
# 9 1.33249484033391e-06 1349.6409072830716
# iteration 0 / 1500: loss 47.520307
# iteration 100 / 1500: loss 22.190950
# iteration 200 / 1500: loss 11.496372
# iteration 300 / 1500: loss 6.418111
# iteration 400 / 1500: loss 4.157137
# iteration 500 / 1500: loss 2.896918
# iteration 600 / 1500: loss 2.373581
# iteration 700 / 1500: loss 2.122253
# iteration 800 / 1500: loss 1.949133
# iteration 900 / 1500: loss 1.988618
# iteration 1000 / 1500: loss 1.949528
# iteration 1100 / 1500: loss 1.795051
# iteration 1200 / 1500: loss 1.880312
# iteration 1300 / 1500: loss 1.868637
# iteration 1400 / 1500: loss 1.837539
# training accuracy: 0.393857
# validation accuracy: 0.388000
# 10 1.1235587698464423e-06 1412.826779946819
# iteration 0 / 1500: loss 49.201509
# iteration 100 / 1500: loss 25.188477
# iteration 200 / 1500: loss 13.911087
# iteration 300 / 1500: loss 8.147845
# iteration 400 / 1500: loss 5.038571
# iteration 500 / 1500: loss 3.605466
# iteration 600 / 1500: loss 2.797872
# iteration 700 / 1500: loss 2.328094
# iteration 800 / 1500: loss 2.106064
# iteration 900 / 1500: loss 1.978816
# iteration 1000 / 1500: loss 1.938687
# iteration 1100 / 1500: loss 1.867325
# iteration 1200 / 1500: loss 1.855105
# iteration 1300 / 1500: loss 1.946566
# iteration 1400 / 1500: loss 1.817900
# training accuracy: 0.390592
# validation accuracy: 0.392000
# 11 2.4080867012654896e-06 1340.1499802516314
# iteration 0 / 1500: loss 46.499787
# iteration 100 / 1500: loss 12.982284
# iteration 200 / 1500: loss 4.854063
# iteration 300 / 1500: loss 2.608823
# iteration 400 / 1500: loss 2.008778
# iteration 500 / 1500: loss 1.927048
# iteration 600 / 1500: loss 1.983375
# iteration 700 / 1500: loss 1.968027
# iteration 800 / 1500: loss 1.788473
# iteration 900 / 1500: loss 1.888963
# iteration 1000 / 1500: loss 1.962490
# iteration 1100 / 1500: loss 1.780022
# iteration 1200 / 1500: loss 1.841503
# iteration 1300 / 1500: loss 1.839204
# iteration 1400 / 1500: loss 1.881302
# training accuracy: 0.393429
# validation accuracy: 0.386000
# 12 2.558060302266595e-06 1384.9258281847735
# iteration 0 / 1500: loss 48.997716
# iteration 100 / 1500: loss 12.047372
# iteration 200 / 1500: loss 4.291439
# iteration 300 / 1500: loss 2.380012
# iteration 400 / 1500: loss 2.082972
# iteration 500 / 1500: loss 1.918858
# iteration 600 / 1500: loss 1.964190
# iteration 700 / 1500: loss 1.908065
# iteration 800 / 1500: loss 1.917471
# iteration 900 / 1500: loss 2.054841
# iteration 1000 / 1500: loss 1.887755
# iteration 1100 / 1500: loss 1.918567
# iteration 1200 / 1500: loss 1.933401
# iteration 1300 / 1500: loss 1.893150
# iteration 1400 / 1500: loss 1.887594
# training accuracy: 0.390551
# validation accuracy: 0.383000
# 13 1.1459046068393759e-06 716.3797215305483
# iteration 0 / 1500: loss 27.715167
# iteration 100 / 1500: loss 18.263606
# iteration 200 / 1500: loss 13.403191
# iteration 300 / 1500: loss 10.072607
# iteration 400 / 1500: loss 7.559877
# iteration 500 / 1500: loss 6.023884
# iteration 600 / 1500: loss 4.711014
# iteration 700 / 1500: loss 3.816843
# iteration 800 / 1500: loss 3.369710
# iteration 900 / 1500: loss 3.026040
# iteration 1000 / 1500: loss 2.624387
# iteration 1100 / 1500: loss 2.372552
# iteration 1200 / 1500: loss 2.234912
# iteration 1300 / 1500: loss 2.204903
# iteration 1400 / 1500: loss 1.971809
# training accuracy: 0.401286
# validation accuracy: 0.393000
# 14 2.3429800510493884e-06 807.3848692618576
# iteration 0 / 1500: loss 30.167576
# iteration 100 / 1500: loss 13.170672
# iteration 200 / 1500: loss 6.906374
# iteration 300 / 1500: loss 4.235018
# iteration 400 / 1500: loss 3.010353
# iteration 500 / 1500: loss 2.253878
# iteration 600 / 1500: loss 2.140166
# iteration 700 / 1500: loss 1.997809
# iteration 800 / 1500: loss 1.893295
# iteration 900 / 1500: loss 1.902070
# iteration 1000 / 1500: loss 1.892042
# iteration 1100 / 1500: loss 1.800415
# iteration 1200 / 1500: loss 1.819930
# iteration 1300 / 1500: loss 1.757124
# iteration 1400 / 1500: loss 1.847234
# training accuracy: 0.396265
# validation accuracy: 0.395000
# 15 1.8361016242523854e-06 1182.665542904217
# iteration 0 / 1500: loss 41.571747
# iteration 100 / 1500: loss 16.721777
# iteration 200 / 1500: loss 7.955595
# iteration 300 / 1500: loss 4.411112
# iteration 400 / 1500: loss 2.930462
# iteration 500 / 1500: loss 2.335350
# iteration 600 / 1500: loss 1.963879
# iteration 700 / 1500: loss 2.000753
# iteration 800 / 1500: loss 1.884543
# iteration 900 / 1500: loss 1.915888
# iteration 1000 / 1500: loss 1.808480
# iteration 1100 / 1500: loss 1.903563
# iteration 1200 / 1500: loss 1.826616
# iteration 1300 / 1500: loss 1.858616
# iteration 1400 / 1500: loss 1.792395
# training accuracy: 0.392898
# validation accuracy: 0.399000
# 16 2.406522409175384e-06 594.5800215388388
# iteration 0 / 1500: loss 24.094663
# iteration 100 / 1500: loss 12.093703
# iteration 200 / 1500: loss 7.551749
# iteration 300 / 1500: loss 4.986596
# iteration 400 / 1500: loss 3.696977
# iteration 500 / 1500: loss 2.663497
# iteration 600 / 1500: loss 2.292343
# iteration 700 / 1500: loss 2.126989
# iteration 800 / 1500: loss 2.083408
# iteration 900 / 1500: loss 2.022863
# iteration 1000 / 1500: loss 1.864974
# iteration 1100 / 1500: loss 1.886928
# iteration 1200 / 1500: loss 1.835299
# iteration 1300 / 1500: loss 1.817499
# iteration 1400 / 1500: loss 1.888320
# training accuracy: 0.394204
# validation accuracy: 0.380000
# 17 1.0246309479582918e-06 875.1243257779547
# iteration 0 / 1500: loss 33.008278
# iteration 100 / 1500: loss 21.119489
# iteration 200 / 1500: loss 15.099187
# iteration 300 / 1500: loss 10.909230
# iteration 400 / 1500: loss 8.154038
# iteration 500 / 1500: loss 6.218465
# iteration 600 / 1500: loss 4.822578
# iteration 700 / 1500: loss 3.811562
# iteration 800 / 1500: loss 3.287111
# iteration 900 / 1500: loss 2.734156
# iteration 1000 / 1500: loss 2.530933
# iteration 1100 / 1500: loss 2.311946
# iteration 1200 / 1500: loss 2.149536
# iteration 1300 / 1500: loss 2.030992
# iteration 1400 / 1500: loss 2.037933
# training accuracy: 0.405531
# validation accuracy: 0.400000
# 18 2.897057356841835e-06 901.4043110127998
# iteration 0 / 1500: loss 33.731799
# iteration 100 / 1500: loss 11.395422
# iteration 200 / 1500: loss 5.037234
# iteration 300 / 1500: loss 3.098301
# iteration 400 / 1500: loss 2.254011
# iteration 500 / 1500: loss 1.910621
# iteration 600 / 1500: loss 1.916782
# iteration 700 / 1500: loss 1.837025
# iteration 800 / 1500: loss 1.744439
# iteration 900 / 1500: loss 1.827391
# iteration 1000 / 1500: loss 1.949998
# iteration 1100 / 1500: loss 1.844827
# iteration 1200 / 1500: loss 1.851318
# iteration 1300 / 1500: loss 1.768741
# iteration 1400 / 1500: loss 1.905083
# training accuracy: 0.377714
# validation accuracy: 0.368000
# 19 1.9660017473176644e-06 1048.5629159569617
# iteration 0 / 1500: loss 37.761448
# iteration 100 / 1500: loss 16.088709
# iteration 200 / 1500: loss 7.969687
# iteration 300 / 1500: loss 4.390374
# iteration 400 / 1500: loss 3.032018
# iteration 500 / 1500: loss 2.381033
# iteration 600 / 1500: loss 2.148915
# iteration 700 / 1500: loss 1.944352
# iteration 800 / 1500: loss 1.899819
# iteration 900 / 1500: loss 1.908886
# iteration 1000 / 1500: loss 1.949583
# iteration 1100 / 1500: loss 1.761171
# iteration 1200 / 1500: loss 1.904748
# iteration 1300 / 1500: loss 1.863424
# iteration 1400 / 1500: loss 1.936411
# training accuracy: 0.397531
# validation accuracy: 0.385000
# 20 1.8766951381758655e-06 854.4718614031211
# iteration 0 / 1500: loss 31.748039
# iteration 100 / 1500: loss 15.886177
# iteration 200 / 1500: loss 9.151106
# iteration 300 / 1500: loss 5.681840
# iteration 400 / 1500: loss 3.752181
# iteration 500 / 1500: loss 2.784570
# iteration 600 / 1500: loss 2.394733
# iteration 700 / 1500: loss 2.080738
# iteration 800 / 1500: loss 2.028757
# iteration 900 / 1500: loss 1.911439
# iteration 1000 / 1500: loss 1.899478
# iteration 1100 / 1500: loss 1.790551
# iteration 1200 / 1500: loss 1.882877
# iteration 1300 / 1500: loss 1.869412
# iteration 1400 / 1500: loss 1.849907
# training accuracy: 0.406000
# validation accuracy: 0.392000
# 21 1.5601246986852045e-06 1480.8745189105514
# iteration 0 / 1500: loss 51.460460
# iteration 100 / 1500: loss 19.763862
# iteration 200 / 1500: loss 8.775424
# iteration 300 / 1500: loss 4.710869
# iteration 400 / 1500: loss 2.932665
# iteration 500 / 1500: loss 2.193138
# iteration 600 / 1500: loss 2.054502
# iteration 700 / 1500: loss 1.986319
# iteration 800 / 1500: loss 1.858689
# iteration 900 / 1500: loss 1.822029
# iteration 1000 / 1500: loss 1.875212
# iteration 1100 / 1500: loss 1.836112
# iteration 1200 / 1500: loss 1.778444
# iteration 1300 / 1500: loss 1.839469
# iteration 1400 / 1500: loss 1.906851
# training accuracy: 0.392000
# validation accuracy: 0.390000
# 22 1.2836787419685065e-06 872.3600034852411
# iteration 0 / 1500: loss 32.394523
# iteration 100 / 1500: loss 19.336179
# iteration 200 / 1500: loss 12.870383
# iteration 300 / 1500: loss 8.765031
# iteration 400 / 1500: loss 6.318652
# iteration 500 / 1500: loss 4.643955
# iteration 600 / 1500: loss 3.564366
# iteration 700 / 1500: loss 2.974391
# iteration 800 / 1500: loss 2.468975
# iteration 900 / 1500: loss 2.325678
# iteration 1000 / 1500: loss 2.134626
# iteration 1100 / 1500: loss 2.020093
# iteration 1200 / 1500: loss 2.028531
# iteration 1300 / 1500: loss 1.847365
# iteration 1400 / 1500: loss 1.845047
# training accuracy: 0.404020
# validation accuracy: 0.405000
# 23 1.7513537227821635e-06 988.254646112585
# iteration 0 / 1500: loss 35.979928
# iteration 100 / 1500: loss 17.190891
# iteration 200 / 1500: loss 9.357806
# iteration 300 / 1500: loss 5.448538
# iteration 400 / 1500: loss 3.646927
# iteration 500 / 1500: loss 2.697396
# iteration 600 / 1500: loss 2.331449
# iteration 700 / 1500: loss 2.056732
# iteration 800 / 1500: loss 1.827243
# iteration 900 / 1500: loss 1.824737
# iteration 1000 / 1500: loss 1.908708
# iteration 1100 / 1500: loss 1.871212
# iteration 1200 / 1500: loss 1.799099
# iteration 1300 / 1500: loss 1.904836
# iteration 1400 / 1500: loss 1.863002
# training accuracy: 0.391245
# validation accuracy: 0.391000
# 24 2.307267601938702e-06 1289.981878295217
# iteration 0 / 1500: loss 45.092100
# iteration 100 / 1500: loss 13.742397
# iteration 200 / 1500: loss 5.387092
# iteration 300 / 1500: loss 2.805806
# iteration 400 / 1500: loss 2.289912
# iteration 500 / 1500: loss 2.024923
# iteration 600 / 1500: loss 2.017026
# iteration 700 / 1500: loss 1.825247
# iteration 800 / 1500: loss 1.979835
# iteration 900 / 1500: loss 1.853744
# iteration 1000 / 1500: loss 1.890046
# iteration 1100 / 1500: loss 1.898919
# iteration 1200 / 1500: loss 1.866120
# iteration 1300 / 1500: loss 1.904559
# iteration 1400 / 1500: loss 1.848857
# training accuracy: 0.375694
# validation accuracy: 0.372000
# 25 2.4470306074856677e-06 887.0401097041778
# iteration 0 / 1500: loss 31.795540
# iteration 100 / 1500: loss 13.204959
# iteration 200 / 1500: loss 6.525507
# iteration 300 / 1500: loss 3.850239
# iteration 400 / 1500: loss 2.631514
# iteration 500 / 1500: loss 2.121982
# iteration 600 / 1500: loss 2.067241
# iteration 700 / 1500: loss 1.924366
# iteration 800 / 1500: loss 1.811646
# iteration 900 / 1500: loss 1.879369
# iteration 1000 / 1500: loss 1.875523
# iteration 1100 / 1500: loss 1.798856
# iteration 1200 / 1500: loss 1.900343
# iteration 1300 / 1500: loss 1.800839
# iteration 1400 / 1500: loss 1.862675
# training accuracy: 0.380041
# validation accuracy: 0.398000
# 26 2.572191733965191e-06 659.5774979197263
# iteration 0 / 1500: loss 25.833584
# iteration 100 / 1500: loss 12.290106
# iteration 200 / 1500: loss 7.022105
# iteration 300 / 1500: loss 4.436533
# iteration 400 / 1500: loss 3.121276
# iteration 500 / 1500: loss 2.420079
# iteration 600 / 1500: loss 2.098494
# iteration 700 / 1500: loss 1.979496
# iteration 800 / 1500: loss 1.873095
# iteration 900 / 1500: loss 1.922449
# iteration 1000 / 1500: loss 1.769763
# iteration 1100 / 1500: loss 1.761784
# iteration 1200 / 1500: loss 1.813506
# iteration 1300 / 1500: loss 1.784625
# iteration 1400 / 1500: loss 1.858920
# training accuracy: 0.396980
# validation accuracy: 0.394000
# 27 1.6385498215254896e-06 810.0633433329314
# iteration 0 / 1500: loss 29.668264
# iteration 100 / 1500: loss 16.574599
# iteration 200 / 1500: loss 10.252161
# iteration 300 / 1500: loss 6.745235
# iteration 400 / 1500: loss 4.713294
# iteration 500 / 1500: loss 3.517806
# iteration 600 / 1500: loss 2.875230
# iteration 700 / 1500: loss 2.460913
# iteration 800 / 1500: loss 2.137180
# iteration 900 / 1500: loss 2.067635
# iteration 1000 / 1500: loss 1.908444
# iteration 1100 / 1500: loss 1.876729
# iteration 1200 / 1500: loss 1.900321
# iteration 1300 / 1500: loss 1.762363
# iteration 1400 / 1500: loss 1.738480
# training accuracy: 0.397959
# validation accuracy: 0.413000
# 28 1.1137443856545295e-06 683.079392823375
# iteration 0 / 1500: loss 26.484996
# iteration 100 / 1500: loss 17.518874
# iteration 200 / 1500: loss 13.205594
# iteration 300 / 1500: loss 9.940635
# iteration 400 / 1500: loss 7.899490
# iteration 500 / 1500: loss 6.384298
# iteration 600 / 1500: loss 5.071803
# iteration 700 / 1500: loss 4.107165
# iteration 800 / 1500: loss 3.563024
# iteration 900 / 1500: loss 3.011056
# iteration 1000 / 1500: loss 2.759721
# iteration 1100 / 1500: loss 2.615156
# iteration 1200 / 1500: loss 2.348541
# iteration 1300 / 1500: loss 2.195091
# iteration 1400 / 1500: loss 1.971696
# training accuracy: 0.404918
# validation accuracy: 0.419000
# 29 2.875366309651143e-06 1405.1392325615532
# iteration 0 / 1500: loss 48.934902
# iteration 100 / 1500: loss 10.369202
# iteration 200 / 1500: loss 3.521043
# iteration 300 / 1500: loss 2.195231
# iteration 400 / 1500: loss 1.902462
# iteration 500 / 1500: loss 1.869981
# iteration 600 / 1500: loss 1.834955
# iteration 700 / 1500: loss 1.816727
# iteration 800 / 1500: loss 1.825378
# iteration 900 / 1500: loss 1.943465
# iteration 1000 / 1500: loss 1.922388
# iteration 1100 / 1500: loss 1.849722
# iteration 1200 / 1500: loss 1.834077
# iteration 1300 / 1500: loss 1.884076
# iteration 1400 / 1500: loss 1.932537
# training accuracy: 0.385918
# validation accuracy: 0.389000
# 30 1.4463277063082443e-06 766.6931661167739
# iteration 0 / 1500: loss 29.616772
# iteration 100 / 1500: loss 17.026365
# iteration 200 / 1500: loss 11.541301
# iteration 300 / 1500: loss 7.990983
# iteration 400 / 1500: loss 5.751201
# iteration 500 / 1500: loss 4.173844
# iteration 600 / 1500: loss 3.422397
# iteration 700 / 1500: loss 2.810123
# iteration 800 / 1500: loss 2.403597
# iteration 900 / 1500: loss 2.081650
# iteration 1000 / 1500: loss 2.000264
# iteration 1100 / 1500: loss 1.980750
# iteration 1200 / 1500: loss 2.084125
# iteration 1300 / 1500: loss 1.913880
# iteration 1400 / 1500: loss 1.832213
# training accuracy: 0.400000
# validation accuracy: 0.379000
# 31 2.7911307624604266e-06 1086.4148348874749
# iteration 0 / 1500: loss 39.343777
# iteration 100 / 1500: loss 11.927484
# iteration 200 / 1500: loss 4.642981
# iteration 300 / 1500: loss 2.695891
# iteration 400 / 1500: loss 2.129835
# iteration 500 / 1500: loss 1.979468
# iteration 600 / 1500: loss 1.875311
# iteration 700 / 1500: loss 1.813538
# iteration 800 / 1500: loss 1.855843
# iteration 900 / 1500: loss 1.841881
# iteration 1000 / 1500: loss 1.871863
# iteration 1100 / 1500: loss 1.907188
# iteration 1200 / 1500: loss 1.914729
# iteration 1300 / 1500: loss 1.914508
# iteration 1400 / 1500: loss 1.729832
# training accuracy: 0.379184
# validation accuracy: 0.367000
# 32 2.29300008171328e-06 719.7337980664931
# iteration 0 / 1500: loss 27.165019
# iteration 100 / 1500: loss 13.154840
# iteration 200 / 1500: loss 7.522838
# iteration 300 / 1500: loss 4.743300
# iteration 400 / 1500: loss 3.336381
# iteration 500 / 1500: loss 2.789968
# iteration 600 / 1500: loss 2.259311
# iteration 700 / 1500: loss 1.879449
# iteration 800 / 1500: loss 1.984860
# iteration 900 / 1500: loss 1.919647
# iteration 1000 / 1500: loss 1.947534
# iteration 1100 / 1500: loss 1.775122
# iteration 1200 / 1500: loss 1.784703
# iteration 1300 / 1500: loss 1.869225
# iteration 1400 / 1500: loss 1.864265
# training accuracy: 0.391531
# validation accuracy: 0.403000
# 33 1.0484346875350878e-06 1342.0415989092967
# iteration 0 / 1500: loss 46.665139
# iteration 100 / 1500: loss 25.427541
# iteration 200 / 1500: loss 15.043167
# iteration 300 / 1500: loss 9.342673
# iteration 400 / 1500: loss 6.108065
# iteration 500 / 1500: loss 4.143475
# iteration 600 / 1500: loss 3.250826
# iteration 700 / 1500: loss 2.596876
# iteration 800 / 1500: loss 2.183306
# iteration 900 / 1500: loss 2.200346
# iteration 1000 / 1500: loss 2.046489
# iteration 1100 / 1500: loss 1.934122
# iteration 1200 / 1500: loss 1.898375
# iteration 1300 / 1500: loss 1.769478
# iteration 1400 / 1500: loss 1.818863
# training accuracy: 0.398061
# validation accuracy: 0.399000
# 34 1.5751148984361538e-06 1431.091720859185
# iteration 0 / 1500: loss 49.845318
# iteration 100 / 1500: loss 19.752352
# iteration 200 / 1500: loss 8.983491
# iteration 300 / 1500: loss 4.667541
# iteration 400 / 1500: loss 3.101279
# iteration 500 / 1500: loss 2.279911
# iteration 600 / 1500: loss 2.030309
# iteration 700 / 1500: loss 1.844021
# iteration 800 / 1500: loss 1.833018
# iteration 900 / 1500: loss 1.884606
# iteration 1000 / 1500: loss 1.877085
# iteration 1100 / 1500: loss 1.871433
# iteration 1200 / 1500: loss 1.870087
# iteration 1300 / 1500: loss 1.988133
# iteration 1400 / 1500: loss 1.905685
# training accuracy: 0.392755
# validation accuracy: 0.398000
# 35 2.6595157955263077e-06 1312.0093405116581
# iteration 0 / 1500: loss 47.590475
# iteration 100 / 1500: loss 11.646833
# iteration 200 / 1500: loss 4.188001
# iteration 300 / 1500: loss 2.492839
# iteration 400 / 1500: loss 2.015464
# iteration 500 / 1500: loss 1.909199
# iteration 600 / 1500: loss 1.874509
# iteration 700 / 1500: loss 1.896796
# iteration 800 / 1500: loss 1.838055
# iteration 900 / 1500: loss 1.994895
# iteration 1000 / 1500: loss 2.001883
# iteration 1100 / 1500: loss 1.854267
# iteration 1200 / 1500: loss 1.980998
# iteration 1300 / 1500: loss 1.950880
# iteration 1400 / 1500: loss 1.865248
# training accuracy: 0.388000
# validation accuracy: 0.393000
# 36 1.0750866601732536e-06 1061.9472662957219
# iteration 0 / 1500: loss 37.643029
# iteration 100 / 1500: loss 22.811375
# iteration 200 / 1500: loss 14.980714
# iteration 300 / 1500: loss 9.913750
# iteration 400 / 1500: loss 7.019772
# iteration 500 / 1500: loss 5.040602
# iteration 600 / 1500: loss 3.841323
# iteration 700 / 1500: loss 3.108550
# iteration 800 / 1500: loss 2.638812
# iteration 900 / 1500: loss 2.276212
# iteration 1000 / 1500: loss 2.133767
# iteration 1100 / 1500: loss 2.073774
# iteration 1200 / 1500: loss 1.982434
# iteration 1300 / 1500: loss 1.846602
# iteration 1400 / 1500: loss 1.892290
# training accuracy: 0.403286
# validation accuracy: 0.401000
# 37 2.032280181334629e-06 1134.4021525623893
# iteration 0 / 1500: loss 41.456578
# iteration 100 / 1500: loss 15.695720
# iteration 200 / 1500: loss 7.183776
# iteration 300 / 1500: loss 3.906129
# iteration 400 / 1500: loss 2.702820
# iteration 500 / 1500: loss 2.194724
# iteration 600 / 1500: loss 1.992660
# iteration 700 / 1500: loss 1.984100
# iteration 800 / 1500: loss 1.899078
# iteration 900 / 1500: loss 1.928127
# iteration 1000 / 1500: loss 1.924680
# iteration 1100 / 1500: loss 1.807920
# iteration 1200 / 1500: loss 1.866639
# iteration 1300 / 1500: loss 1.904099
# iteration 1400 / 1500: loss 1.880890
# training accuracy: 0.394796
# validation accuracy: 0.394000
# 38 2.2764501727784095e-06 1084.5518722276872
# iteration 0 / 1500: loss 39.391689
# iteration 100 / 1500: loss 14.184935
# iteration 200 / 1500: loss 6.372665
# iteration 300 / 1500: loss 3.561970
# iteration 400 / 1500: loss 2.463219
# iteration 500 / 1500: loss 2.016595
# iteration 600 / 1500: loss 1.948449
# iteration 700 / 1500: loss 1.893964
# iteration 800 / 1500: loss 1.729797
# iteration 900 / 1500: loss 1.885015
# iteration 1000 / 1500: loss 1.800411
# iteration 1100 / 1500: loss 1.916964
# iteration 1200 / 1500: loss 1.940565
# iteration 1300 / 1500: loss 1.894831
# iteration 1400 / 1500: loss 1.947904
# training accuracy: 0.391796
# validation accuracy: 0.389000
# 39 2.5940305896033e-06 712.7887851248454
# iteration 0 / 1500: loss 28.233737
# iteration 100 / 1500: loss 12.363314
# iteration 200 / 1500: loss 6.890413
# iteration 300 / 1500: loss 4.288016
# iteration 400 / 1500: loss 2.904175
# iteration 500 / 1500: loss 2.309551
# iteration 600 / 1500: loss 2.126016
# iteration 700 / 1500: loss 2.001189
# iteration 800 / 1500: loss 1.879434
# iteration 900 / 1500: loss 1.910131
# iteration 1000 / 1500: loss 1.791019
# iteration 1100 / 1500: loss 1.815331
# iteration 1200 / 1500: loss 1.909745
# iteration 1300 / 1500: loss 1.953669
# iteration 1400 / 1500: loss 1.824290
# training accuracy: 0.392408
# validation accuracy: 0.397000
# 40 1.9141359095282336e-06 531.0445223282353
# iteration 0 / 1500: loss 22.224253
# iteration 100 / 1500: loss 12.797034
# iteration 200 / 1500: loss 8.843568
# iteration 300 / 1500: loss 6.388291
# iteration 400 / 1500: loss 4.798589
# iteration 500 / 1500: loss 3.908289
# iteration 600 / 1500: loss 3.137660
# iteration 700 / 1500: loss 2.567357
# iteration 800 / 1500: loss 2.427310
# iteration 900 / 1500: loss 2.221589
# iteration 1000 / 1500: loss 2.085775
# iteration 1100 / 1500: loss 2.068999
# iteration 1200 / 1500: loss 1.922917
# iteration 1300 / 1500: loss 1.813680
# iteration 1400 / 1500: loss 1.750334
# training accuracy: 0.402143
# validation accuracy: 0.394000
# 41 2.602161385548262e-06 1102.5278789721547
# iteration 0 / 1500: loss 39.655897
# iteration 100 / 1500: loss 12.383293
# iteration 200 / 1500: loss 5.162690
# iteration 300 / 1500: loss 2.808454
# iteration 400 / 1500: loss 2.092652
# iteration 500 / 1500: loss 2.049994
# iteration 600 / 1500: loss 1.840099
# iteration 700 / 1500: loss 1.886486
# iteration 800 / 1500: loss 1.805852
# iteration 900 / 1500: loss 1.812452
# iteration 1000 / 1500: loss 1.830089
# iteration 1100 / 1500: loss 1.924629
# iteration 1200 / 1500: loss 1.838926
# iteration 1300 / 1500: loss 2.034860
# iteration 1400 / 1500: loss 1.879062
# training accuracy: 0.381633
# validation accuracy: 0.396000
# 42 2.6718246584000827e-06 1417.7308068583231
# iteration 0 / 1500: loss 48.649422
# iteration 100 / 1500: loss 11.158266
# iteration 200 / 1500: loss 3.916328
# iteration 300 / 1500: loss 2.204152
# iteration 400 / 1500: loss 1.996101
# iteration 500 / 1500: loss 1.882665
# iteration 600 / 1500: loss 1.923683
# iteration 700 / 1500: loss 1.909949
# iteration 800 / 1500: loss 1.841991
# iteration 900 / 1500: loss 1.823807
# iteration 1000 / 1500: loss 1.865661
# iteration 1100 / 1500: loss 1.870712
# iteration 1200 / 1500: loss 1.798179
# iteration 1300 / 1500: loss 1.851333
# iteration 1400 / 1500: loss 1.836275
# training accuracy: 0.388388
# validation accuracy: 0.373000
# 43 1.5092355739416421e-06 1455.20318340743
# iteration 0 / 1500: loss 50.490424
# iteration 100 / 1500: loss 20.137367
# iteration 200 / 1500: loss 9.328318
# iteration 300 / 1500: loss 4.843070
# iteration 400 / 1500: loss 2.991193
# iteration 500 / 1500: loss 2.366974
# iteration 600 / 1500: loss 2.119843
# iteration 700 / 1500: loss 1.959266
# iteration 800 / 1500: loss 1.774201
# iteration 900 / 1500: loss 1.941016
# iteration 1000 / 1500: loss 1.808059
# iteration 1100 / 1500: loss 1.974764
# iteration 1200 / 1500: loss 1.818381
# iteration 1300 / 1500: loss 1.873256
# iteration 1400 / 1500: loss 1.872191
# training accuracy: 0.387347
# validation accuracy: 0.377000
# 44 1.1677549467761383e-06 990.6939592937717
# iteration 0 / 1500: loss 36.131814
# iteration 100 / 1500: loss 21.266392
# iteration 200 / 1500: loss 13.834266
# iteration 300 / 1500: loss 9.371079
# iteration 400 / 1500: loss 6.502130
# iteration 500 / 1500: loss 4.705565
# iteration 600 / 1500: loss 3.568997
# iteration 700 / 1500: loss 2.925387
# iteration 800 / 1500: loss 2.530927
# iteration 900 / 1500: loss 2.383520
# iteration 1000 / 1500: loss 2.039695
# iteration 1100 / 1500: loss 1.939842
# iteration 1200 / 1500: loss 2.020246
# iteration 1300 / 1500: loss 1.954389
# iteration 1400 / 1500: loss 1.866176
# training accuracy: 0.399592
# validation accuracy: 0.382000
# 45 2.874838236535717e-06 1388.0399681673248
# iteration 0 / 1500: loss 48.009172
# iteration 100 / 1500: loss 10.309831
# iteration 200 / 1500: loss 3.522915
# iteration 300 / 1500: loss 2.215895
# iteration 400 / 1500: loss 1.849893
# iteration 500 / 1500: loss 1.954035
# iteration 600 / 1500: loss 1.911610
# iteration 700 / 1500: loss 1.839031
# iteration 800 / 1500: loss 1.946554
# iteration 900 / 1500: loss 1.831326
# iteration 1000 / 1500: loss 1.922186
# iteration 1100 / 1500: loss 1.843704
# iteration 1200 / 1500: loss 1.849124
# iteration 1300 / 1500: loss 1.932040
# iteration 1400 / 1500: loss 1.974521
# training accuracy: 0.383265
# validation accuracy: 0.394000
# 46 1.565544185015347e-06 600.3618798540068
# iteration 0 / 1500: loss 23.962210
# iteration 100 / 1500: loss 14.809924
# iteration 200 / 1500: loss 10.561198
# iteration 300 / 1500: loss 7.843586
# iteration 400 / 1500: loss 5.761887
# iteration 500 / 1500: loss 4.600459
# iteration 600 / 1500: loss 3.797204
# iteration 700 / 1500: loss 3.109352
# iteration 800 / 1500: loss 2.490904
# iteration 900 / 1500: loss 2.329947
# iteration 1000 / 1500: loss 2.333267
# iteration 1100 / 1500: loss 2.073941
# iteration 1200 / 1500: loss 1.964152
# iteration 1300 / 1500: loss 2.069009
# iteration 1400 / 1500: loss 1.968361
# training accuracy: 0.405755
# validation accuracy: 0.398000
# 47 1.4939019427571918e-06 513.9703069812211
# iteration 0 / 1500: loss 21.871299
# iteration 100 / 1500: loss 13.903497
# iteration 200 / 1500: loss 10.433074
# iteration 300 / 1500: loss 7.957787
# iteration 400 / 1500: loss 6.255408
# iteration 500 / 1500: loss 4.987374
# iteration 600 / 1500: loss 4.089660
# iteration 700 / 1500: loss 3.527835
# iteration 800 / 1500: loss 3.015026
# iteration 900 / 1500: loss 2.777579
# iteration 1000 / 1500: loss 2.485608
# iteration 1100 / 1500: loss 2.344096
# iteration 1200 / 1500: loss 2.103338
# iteration 1300 / 1500: loss 2.063153
# iteration 1400 / 1500: loss 2.048756
# training accuracy: 0.409469
# validation accuracy: 0.401000
# 48 2.6906663286539253e-06 516.2187237242424
# iteration 0 / 1500: loss 21.072837
# iteration 100 / 1500: loss 10.859491
# iteration 200 / 1500: loss 6.773358
# iteration 300 / 1500: loss 4.739370
# iteration 400 / 1500: loss 3.467512
# iteration 500 / 1500: loss 2.664237
# iteration 600 / 1500: loss 2.357143
# iteration 700 / 1500: loss 2.047196
# iteration 800 / 1500: loss 1.976472
# iteration 900 / 1500: loss 1.760356
# iteration 1000 / 1500: loss 1.901133
# iteration 1100 / 1500: loss 1.804116
# iteration 1200 / 1500: loss 1.816746
# iteration 1300 / 1500: loss 1.790310
# iteration 1400 / 1500: loss 1.937736
# training accuracy: 0.396592
# validation accuracy: 0.387000
# 49 1.515372922505161e-06 1373.5360233099718
# iteration 0 / 1500: loss 47.269066
# iteration 100 / 1500: loss 19.974291
# iteration 200 / 1500: loss 9.560115
# iteration 300 / 1500: loss 5.297157
# iteration 400 / 1500: loss 3.247424
# iteration 500 / 1500: loss 2.436228
# iteration 600 / 1500: loss 2.161524
# iteration 700 / 1500: loss 1.967948
# iteration 800 / 1500: loss 2.024003
# iteration 900 / 1500: loss 1.847161
# iteration 1000 / 1500: loss 1.855980
# iteration 1100 / 1500: loss 1.908366
# iteration 1200 / 1500: loss 1.818204
# iteration 1300 / 1500: loss 1.828130
# iteration 1400 / 1500: loss 1.904058
# training accuracy: 0.381694
# validation accuracy: 0.393000
# 50 2.7891147292214937e-06 610.7674883182439
# iteration 0 / 1500: loss 23.721734
# iteration 100 / 1500: loss 11.256898
# iteration 200 / 1500: loss 6.486353
# iteration 300 / 1500: loss 4.114102
# iteration 400 / 1500: loss 3.069572
# iteration 500 / 1500: loss 2.430282
# iteration 600 / 1500: loss 2.099647
# iteration 700 / 1500: loss 2.036153
# iteration 800 / 1500: loss 2.009291
# iteration 900 / 1500: loss 1.920070
# iteration 1000 / 1500: loss 1.885936
# iteration 1100 / 1500: loss 1.885889
# iteration 1200 / 1500: loss 1.837563
# iteration 1300 / 1500: loss 1.849140
# iteration 1400 / 1500: loss 1.856375
# training accuracy: 0.393653
# validation accuracy: 0.396000
# 51 1.8978469245297874e-06 832.3235673763838
# iteration 0 / 1500: loss 31.400636
# iteration 100 / 1500: loss 15.667730
# iteration 200 / 1500: loss 8.937305
# iteration 300 / 1500: loss 5.600184
# iteration 400 / 1500: loss 3.791830
# iteration 500 / 1500: loss 2.841470
# iteration 600 / 1500: loss 2.316119
# iteration 700 / 1500: loss 2.170915
# iteration 800 / 1500: loss 2.014718
# iteration 900 / 1500: loss 1.924193
# iteration 1000 / 1500: loss 1.819070
# iteration 1100 / 1500: loss 1.833714
# iteration 1200 / 1500: loss 1.758904
# iteration 1300 / 1500: loss 1.915409
# iteration 1400 / 1500: loss 1.909149
# training accuracy: 0.397388
# validation accuracy: 0.396000
# 52 2.884159111411141e-06 881.8171994766661
# iteration 0 / 1500: loss 32.319381
# iteration 100 / 1500: loss 11.353787
# iteration 200 / 1500: loss 5.187538
# iteration 300 / 1500: loss 2.969760
# iteration 400 / 1500: loss 2.231371
# iteration 500 / 1500: loss 1.941903
# iteration 600 / 1500: loss 1.903302
# iteration 700 / 1500: loss 1.868104
# iteration 800 / 1500: loss 1.874144
# iteration 900 / 1500: loss 1.831179
# iteration 1000 / 1500: loss 1.862618
# iteration 1100 / 1500: loss 1.994437
# iteration 1200 / 1500: loss 1.927890
# iteration 1300 / 1500: loss 1.824100
# iteration 1400 / 1500: loss 1.811012
# training accuracy: 0.386796
# validation accuracy: 0.384000
# 53 2.9815222025072262e-06 877.2986419149631
# iteration 0 / 1500: loss 32.624765
# iteration 100 / 1500: loss 11.091232
# iteration 200 / 1500: loss 4.982663
# iteration 300 / 1500: loss 2.936034
# iteration 400 / 1500: loss 2.184542
# iteration 500 / 1500: loss 1.995008
# iteration 600 / 1500: loss 1.874963
# iteration 700 / 1500: loss 1.931970
# iteration 800 / 1500: loss 1.846021
# iteration 900 / 1500: loss 1.773211
# iteration 1000 / 1500: loss 1.903931
# iteration 1100 / 1500: loss 1.830091
# iteration 1200 / 1500: loss 1.892924
# iteration 1300 / 1500: loss 1.846922
# iteration 1400 / 1500: loss 1.920842
# training accuracy: 0.394694
# validation accuracy: 0.393000
# 54 2.4332886166423477e-06 1391.169831238442
# iteration 0 / 1500: loss 49.212165
# iteration 100 / 1500: loss 12.886117
# iteration 200 / 1500: loss 4.551989
# iteration 300 / 1500: loss 2.722123
# iteration 400 / 1500: loss 2.096909
# iteration 500 / 1500: loss 1.794714
# iteration 600 / 1500: loss 1.873159
# iteration 700 / 1500: loss 1.939610
# iteration 800 / 1500: loss 1.832975
# iteration 900 / 1500: loss 1.876307
# iteration 1000 / 1500: loss 1.867938
# iteration 1100 / 1500: loss 1.745013
# iteration 1200 / 1500: loss 1.913354
# iteration 1300 / 1500: loss 1.818699
# iteration 1400 / 1500: loss 1.774583
# training accuracy: 0.385653
# validation accuracy: 0.393000
# 55 1.2131777197205665e-06 1415.8842769254688
# iteration 0 / 1500: loss 49.167630
# iteration 100 / 1500: loss 23.714267
# iteration 200 / 1500: loss 12.700439
# iteration 300 / 1500: loss 7.247785
# iteration 400 / 1500: loss 4.558718
# iteration 500 / 1500: loss 3.293940
# iteration 600 / 1500: loss 2.537357
# iteration 700 / 1500: loss 2.151087
# iteration 800 / 1500: loss 2.034773
# iteration 900 / 1500: loss 1.996629
# iteration 1000 / 1500: loss 1.902039
# iteration 1100 / 1500: loss 1.889781
# iteration 1200 / 1500: loss 1.923762
# iteration 1300 / 1500: loss 1.896095
# iteration 1400 / 1500: loss 1.814797
# training accuracy: 0.388612
# validation accuracy: 0.385000
# 56 1.2328570307386602e-06 1387.8635391480402
# iteration 0 / 1500: loss 48.428081
# iteration 100 / 1500: loss 23.642768
# iteration 200 / 1500: loss 12.497757
# iteration 300 / 1500: loss 7.170008
# iteration 400 / 1500: loss 4.546503
# iteration 500 / 1500: loss 3.141930
# iteration 600 / 1500: loss 2.445163
# iteration 700 / 1500: loss 2.313153
# iteration 800 / 1500: loss 2.054185
# iteration 900 / 1500: loss 2.064722
# iteration 1000 / 1500: loss 2.055244
# iteration 1100 / 1500: loss 1.828962
# iteration 1200 / 1500: loss 1.903084
# iteration 1300 / 1500: loss 1.945495
# iteration 1400 / 1500: loss 1.874312
# training accuracy: 0.389857
# validation accuracy: 0.397000
# 57 1.7789249764203414e-06 716.7698645893811
# iteration 0 / 1500: loss 29.214430
# iteration 100 / 1500: loss 15.508490
# iteration 200 / 1500: loss 9.623700
# iteration 300 / 1500: loss 6.450861
# iteration 400 / 1500: loss 4.568094
# iteration 500 / 1500: loss 3.511639
# iteration 600 / 1500: loss 2.814695
# iteration 700 / 1500: loss 2.506607
# iteration 800 / 1500: loss 2.155808
# iteration 900 / 1500: loss 2.039195
# iteration 1000 / 1500: loss 1.875226
# iteration 1100 / 1500: loss 1.872892
# iteration 1200 / 1500: loss 1.964511
# iteration 1300 / 1500: loss 1.861283
# iteration 1400 / 1500: loss 1.870226
# training accuracy: 0.397776
# validation accuracy: 0.387000
# 58 1.953840196010716e-06 556.7190294557521
# iteration 0 / 1500: loss 22.555654
# iteration 100 / 1500: loss 13.213214
# iteration 200 / 1500: loss 8.826411
# iteration 300 / 1500: loss 6.421376
# iteration 400 / 1500: loss 4.714486
# iteration 500 / 1500: loss 3.656143
# iteration 600 / 1500: loss 2.996507
# iteration 700 / 1500: loss 2.563555
# iteration 800 / 1500: loss 2.309568
# iteration 900 / 1500: loss 2.129163
# iteration 1000 / 1500: loss 2.008210
# iteration 1100 / 1500: loss 1.889599
# iteration 1200 / 1500: loss 1.897569
# iteration 1300 / 1500: loss 1.966486
# iteration 1400 / 1500: loss 1.829971
# training accuracy: 0.403122
# validation accuracy: 0.401000
# 59 2.205165449134839e-06 1495.9843814956548
# iteration 0 / 1500: loss 51.395584
# iteration 100 / 1500: loss 14.006704
# iteration 200 / 1500: loss 4.968047
# iteration 300 / 1500: loss 2.784370
# iteration 400 / 1500: loss 2.174115
# iteration 500 / 1500: loss 1.984937
# iteration 600 / 1500: loss 1.781160
# iteration 700 / 1500: loss 1.974325
# iteration 800 / 1500: loss 1.869157
# iteration 900 / 1500: loss 1.867431
# iteration 1000 / 1500: loss 1.910111
# iteration 1100 / 1500: loss 1.786598
# iteration 1200 / 1500: loss 1.827660
# iteration 1300 / 1500: loss 1.873370
# iteration 1400 / 1500: loss 1.857199
# training accuracy: 0.380653
# validation accuracy: 0.378000
# 60 2.4813734920432436e-06 1257.9918819672844
# iteration 0 / 1500: loss 44.765182
# iteration 100 / 1500: loss 12.702335
# iteration 200 / 1500: loss 4.974609
# iteration 300 / 1500: loss 2.680308
# iteration 400 / 1500: loss 2.033346
# iteration 500 / 1500: loss 1.843947
# iteration 600 / 1500: loss 1.942273
# iteration 700 / 1500: loss 1.841270
# iteration 800 / 1500: loss 1.793930
# iteration 900 / 1500: loss 2.005183
# iteration 1000 / 1500: loss 1.810213
# iteration 1100 / 1500: loss 1.933821
# iteration 1200 / 1500: loss 1.872119
# iteration 1300 / 1500: loss 1.825809
# iteration 1400 / 1500: loss 1.961799
# training accuracy: 0.374143
# validation accuracy: 0.373000
# 61 2.781629135872648e-06 973.942068537523
# iteration 0 / 1500: loss 35.463623
# iteration 100 / 1500: loss 11.846555
# iteration 200 / 1500: loss 5.119067
# iteration 300 / 1500: loss 2.931598
# iteration 400 / 1500: loss 2.233129
# iteration 500 / 1500: loss 1.967223
# iteration 600 / 1500: loss 1.891519
# iteration 700 / 1500: loss 1.887110
# iteration 800 / 1500: loss 1.960871
# iteration 900 / 1500: loss 1.845534
# iteration 1000 / 1500: loss 1.821604
# iteration 1100 / 1500: loss 1.777689
# iteration 1200 / 1500: loss 1.985971
# iteration 1300 / 1500: loss 1.964026
# iteration 1400 / 1500: loss 1.839774
# training accuracy: 0.389714
# validation accuracy: 0.393000
# 62 2.4053622823116464e-06 1271.4097580310959
# iteration 0 / 1500: loss 45.366620
# iteration 100 / 1500: loss 13.209494
# iteration 200 / 1500: loss 5.266350
# iteration 300 / 1500: loss 2.847864
# iteration 400 / 1500: loss 2.230368
# iteration 500 / 1500: loss 1.854776
# iteration 600 / 1500: loss 1.917843
# iteration 700 / 1500: loss 1.949851
# iteration 800 / 1500: loss 2.003406
# iteration 900 / 1500: loss 1.874375
# iteration 1000 / 1500: loss 1.943255
# iteration 1100 / 1500: loss 1.831489
# iteration 1200 / 1500: loss 1.845554
# iteration 1300 / 1500: loss 1.940082
# iteration 1400 / 1500: loss 2.007192
# training accuracy: 0.388327
# validation accuracy: 0.375000
# 63 1.7403836874284658e-06 1363.712948047086
# iteration 0 / 1500: loss 47.380592
# iteration 100 / 1500: loss 17.747848
# iteration 200 / 1500: loss 7.915819
# iteration 300 / 1500: loss 4.188359
# iteration 400 / 1500: loss 2.778009
# iteration 500 / 1500: loss 2.177830
# iteration 600 / 1500: loss 1.991117
# iteration 700 / 1500: loss 1.959444
# iteration 800 / 1500: loss 1.834146
# iteration 900 / 1500: loss 1.916882
# iteration 1000 / 1500: loss 1.801241
# iteration 1100 / 1500: loss 1.874988
# iteration 1200 / 1500: loss 1.779297
# iteration 1300 / 1500: loss 1.864385
# iteration 1400 / 1500: loss 1.765510
# training accuracy: 0.389306
# validation accuracy: 0.387000
# 64 1.8640893644351768e-06 1446.887173667752
# iteration 0 / 1500: loss 48.693963
# iteration 100 / 1500: loss 16.805743
# iteration 200 / 1500: loss 6.842882
# iteration 300 / 1500: loss 3.625926
# iteration 400 / 1500: loss 2.448838
# iteration 500 / 1500: loss 2.080508
# iteration 600 / 1500: loss 1.997931
# iteration 700 / 1500: loss 1.975917
# iteration 800 / 1500: loss 1.810457
# iteration 900 / 1500: loss 1.888763
# iteration 1000 / 1500: loss 2.046148
# iteration 1100 / 1500: loss 1.826553
# iteration 1200 / 1500: loss 1.899921
# iteration 1300 / 1500: loss 1.903805
# iteration 1400 / 1500: loss 1.920138
# training accuracy: 0.378878
# validation accuracy: 0.395000
# 65 2.2480234780020076e-06 636.7145115727478
# iteration 0 / 1500: loss 24.725370
# iteration 100 / 1500: loss 12.869232
# iteration 200 / 1500: loss 7.827934
# iteration 300 / 1500: loss 5.090328
# iteration 400 / 1500: loss 3.606472
# iteration 500 / 1500: loss 2.844716
# iteration 600 / 1500: loss 2.501547
# iteration 700 / 1500: loss 2.059936
# iteration 800 / 1500: loss 1.881482
# iteration 900 / 1500: loss 1.803773
# iteration 1000 / 1500: loss 1.791582
# iteration 1100 / 1500: loss 1.887407
# iteration 1200 / 1500: loss 1.975260
# iteration 1300 / 1500: loss 1.766039
# iteration 1400 / 1500: loss 1.759512
# training accuracy: 0.383347
# validation accuracy: 0.373000
# 66 1.81536602943402e-06 1219.6751966584288
# iteration 0 / 1500: loss 43.026492
# iteration 100 / 1500: loss 17.013345
# iteration 200 / 1500: loss 8.008588
# iteration 300 / 1500: loss 4.422890
# iteration 400 / 1500: loss 2.871826
# iteration 500 / 1500: loss 2.284693
# iteration 600 / 1500: loss 2.064639
# iteration 700 / 1500: loss 1.977808
# iteration 800 / 1500: loss 1.821463
# iteration 900 / 1500: loss 1.934387
# iteration 1000 / 1500: loss 2.027576
# iteration 1100 / 1500: loss 1.909690
# iteration 1200 / 1500: loss 1.831512
# iteration 1300 / 1500: loss 2.047437
# iteration 1400 / 1500: loss 1.863625
# training accuracy: 0.390735
# validation accuracy: 0.404000
# 67 1.966486361399412e-06 1266.5349743849501
# iteration 0 / 1500: loss 44.665451
# iteration 100 / 1500: loss 16.266516
# iteration 200 / 1500: loss 6.984039
# iteration 300 / 1500: loss 3.776082
# iteration 400 / 1500: loss 2.523531
# iteration 500 / 1500: loss 2.012225
# iteration 600 / 1500: loss 1.976855
# iteration 700 / 1500: loss 1.927278
# iteration 800 / 1500: loss 1.869184
# iteration 900 / 1500: loss 1.881901
# iteration 1000 / 1500: loss 1.763793
# iteration 1100 / 1500: loss 1.824982
# iteration 1200 / 1500: loss 1.785759
# iteration 1300 / 1500: loss 1.869245
# iteration 1400 / 1500: loss 1.886526
# training accuracy: 0.391122
# validation accuracy: 0.381000
# 68 1.0897731927346705e-06 1315.3069282960857
# iteration 0 / 1500: loss 46.568373
# iteration 100 / 1500: loss 24.876463
# iteration 200 / 1500: loss 14.649069
# iteration 300 / 1500: loss 8.973465
# iteration 400 / 1500: loss 5.740524
# iteration 500 / 1500: loss 4.027036
# iteration 600 / 1500: loss 3.053323
# iteration 700 / 1500: loss 2.624516
# iteration 800 / 1500: loss 2.145861
# iteration 900 / 1500: loss 2.062455
# iteration 1000 / 1500: loss 2.044137
# iteration 1100 / 1500: loss 1.977474
# iteration 1200 / 1500: loss 1.874520
# iteration 1300 / 1500: loss 1.908423
# iteration 1400 / 1500: loss 1.852276
# training accuracy: 0.389265
# validation accuracy: 0.377000
# 69 2.8233662045177876e-06 879.3100441768647
# iteration 0 / 1500: loss 32.070321
# iteration 100 / 1500: loss 11.536794
# iteration 200 / 1500: loss 5.362729
# iteration 300 / 1500: loss 3.044631
# iteration 400 / 1500: loss 2.335191
# iteration 500 / 1500: loss 2.037166
# iteration 600 / 1500: loss 1.962932
# iteration 700 / 1500: loss 1.816247
# iteration 800 / 1500: loss 1.837961
# iteration 900 / 1500: loss 1.899433
# iteration 1000 / 1500: loss 1.774653
# iteration 1100 / 1500: loss 1.866408
# iteration 1200 / 1500: loss 1.817660
# iteration 1300 / 1500: loss 1.861474
# iteration 1400 / 1500: loss 1.812823
# training accuracy: 0.381918
# validation accuracy: 0.386000
# 70 1.3980278605505628e-06 1113.0144998616126
# iteration 0 / 1500: loss 38.979320
# iteration 100 / 1500: loss 20.399107
# iteration 200 / 1500: loss 11.678786
# iteration 300 / 1500: loss 6.952617
# iteration 400 / 1500: loss 4.553572
# iteration 500 / 1500: loss 3.239732
# iteration 600 / 1500: loss 2.613511
# iteration 700 / 1500: loss 2.373587
# iteration 800 / 1500: loss 1.922479
# iteration 900 / 1500: loss 1.966095
# iteration 1000 / 1500: loss 1.969210
# iteration 1100 / 1500: loss 1.957088
# iteration 1200 / 1500: loss 1.844904
# iteration 1300 / 1500: loss 1.889149
# iteration 1400 / 1500: loss 1.821663
# training accuracy: 0.397673
# validation accuracy: 0.400000
# 71 2.1838027655264843e-06 618.5975566269141
# iteration 0 / 1500: loss 25.355343
# iteration 100 / 1500: loss 13.076096
# iteration 200 / 1500: loss 8.402364
# iteration 300 / 1500: loss 5.581707
# iteration 400 / 1500: loss 4.015163
# iteration 500 / 1500: loss 3.036121
# iteration 600 / 1500: loss 2.519052
# iteration 700 / 1500: loss 2.290483
# iteration 800 / 1500: loss 2.051224
# iteration 900 / 1500: loss 2.106256
# iteration 1000 / 1500: loss 1.992207
# iteration 1100 / 1500: loss 1.887297
# iteration 1200 / 1500: loss 1.899527
# iteration 1300 / 1500: loss 1.877264
# iteration 1400 / 1500: loss 1.891035
# training accuracy: 0.395898
# validation accuracy: 0.396000
# 72 2.268874501973757e-06 811.3686481446881
# iteration 0 / 1500: loss 31.429159
# iteration 100 / 1500: loss 13.814142
# iteration 200 / 1500: loss 7.398915
# iteration 300 / 1500: loss 4.433183
# iteration 400 / 1500: loss 3.172601
# iteration 500 / 1500: loss 2.433925
# iteration 600 / 1500: loss 2.061343
# iteration 700 / 1500: loss 2.015977
# iteration 800 / 1500: loss 1.989853
# iteration 900 / 1500: loss 1.858674
# iteration 1000 / 1500: loss 1.933238
# iteration 1100 / 1500: loss 1.888850
# iteration 1200 / 1500: loss 1.765521
# iteration 1300 / 1500: loss 1.759880
# iteration 1400 / 1500: loss 1.814467
# training accuracy: 0.400000
# validation accuracy: 0.399000
# 73 2.6144642397877386e-06 1094.0320406408598
# iteration 0 / 1500: loss 38.203020
# iteration 100 / 1500: loss 12.307765
# iteration 200 / 1500: loss 5.207456
# iteration 300 / 1500: loss 2.849517
# iteration 400 / 1500: loss 2.119118
# iteration 500 / 1500: loss 1.953621
# iteration 600 / 1500: loss 1.880727
# iteration 700 / 1500: loss 1.982578
# iteration 800 / 1500: loss 1.907772
# iteration 900 / 1500: loss 1.952652
# iteration 1000 / 1500: loss 1.803596
# iteration 1100 / 1500: loss 1.862953
# iteration 1200 / 1500: loss 1.824701
# iteration 1300 / 1500: loss 1.881916
# iteration 1400 / 1500: loss 1.934649
# training accuracy: 0.381959
# validation accuracy: 0.386000
# 74 2.158335955045503e-06 1383.041330963585
# iteration 0 / 1500: loss 48.267594
# iteration 100 / 1500: loss 14.453939
# ...
# training accuracy: 0.403714
# validation accuracy: 0.402000
# 88 2.0240834542844863e-06 1255.3663851640968
# iteration 0 / 1500: loss 43.980694
# iteration 100 / 1500: loss 15.606245
# iteration 200 / 1500: loss 6.752582
# iteration 300 / 1500: loss 3.648522
# iteration 400 / 1500: loss 2.556062
# iteration 500 / 1500: loss 2.125144
# iteration 600 / 1500: loss 1.903857
# iteration 700 / 1500: loss 1.737644
# iteration 800 / 1500: loss 1.932719
# iteration 900 / 1500: loss 1.813312
# iteration 1000 / 1500: loss 1.826936
# iteration 1100 / 1500: loss 1.817325
# iteration 1200 / 1500: loss 1.868407
# iteration 1300 / 1500: loss 1.936178
# iteration 1400 / 1500: loss 1.899317
# training accuracy: 0.385633
# validation accuracy: 0.383000
# 89 1.292751812821565e-06 1317.7210135240275
# iteration 0 / 1500: loss 45.798030
# iteration 100 / 1500: loss 22.154276
# iteration 200 / 1500: loss 12.079896
# iteration 300 / 1500: loss 6.903682
# iteration 400 / 1500: loss 4.425572
# iteration 500 / 1500: loss 3.188668
# iteration 600 / 1500: loss 2.364264
# iteration 700 / 1500: loss 2.230070
# iteration 800 / 1500: loss 2.022316
# iteration 900 / 1500: loss 1.844611
# iteration 1000 / 1500: loss 1.890222
# iteration 1100 / 1500: loss 1.843236
# iteration 1200 / 1500: loss 1.792219
# iteration 1300 / 1500: loss 1.810944
# iteration 1400 / 1500: loss 1.797058
# training accuracy: 0.394571
# validation accuracy: 0.397000
# 90 2.595708050290267e-06 770.2768589914583
# iteration 0 / 1500: loss 29.295479
# iteration 100 / 1500: loss 12.526034
# iteration 200 / 1500: loss 6.595953
# iteration 300 / 1500: loss 3.910650
# iteration 400 / 1500: loss 2.779062
# iteration 500 / 1500: loss 2.196082
# iteration 600 / 1500: loss 2.039228
# iteration 700 / 1500: loss 1.957880
# iteration 800 / 1500: loss 1.938142
# iteration 900 / 1500: loss 1.911606
# iteration 1000 / 1500: loss 1.879857
# iteration 1100 / 1500: loss 1.827310
# iteration 1200 / 1500: loss 1.804758
# iteration 1300 / 1500: loss 1.836224
# iteration 1400 / 1500: loss 1.901819
# training accuracy: 0.387408
# validation accuracy: 0.393000
# 91 2.159038322535217e-06 1348.6776361189632
# iteration 0 / 1500: loss 47.115192
# iteration 100 / 1500: loss 14.682880
# iteration 200 / 1500: loss 5.819695
# iteration 300 / 1500: loss 2.982660
# iteration 400 / 1500: loss 2.296062
# iteration 500 / 1500: loss 2.120577
# iteration 600 / 1500: loss 1.871021
# iteration 700 / 1500: loss 1.956176
# iteration 800 / 1500: loss 1.874317
# iteration 900 / 1500: loss 2.022233
# iteration 1000 / 1500: loss 2.003017
# iteration 1100 / 1500: loss 1.761499
# iteration 1200 / 1500: loss 1.860901
# iteration 1300 / 1500: loss 1.761736
# iteration 1400 / 1500: loss 1.838396
# training accuracy: 0.387592
# validation accuracy: 0.407000
# 92 1.8363793604903973e-06 1320.1839517879046
# iteration 0 / 1500: loss 45.864136
# iteration 100 / 1500: loss 16.880862
# iteration 200 / 1500: loss 7.549322
# iteration 300 / 1500: loss 3.906000
# iteration 400 / 1500: loss 2.622621
# iteration 500 / 1500: loss 2.133047
# iteration 600 / 1500: loss 1.931754
# iteration 700 / 1500: loss 1.925245
# iteration 800 / 1500: loss 1.875454
# iteration 900 / 1500: loss 1.774752
# iteration 1000 / 1500: loss 1.812359
# iteration 1100 / 1500: loss 2.023445
# iteration 1200 / 1500: loss 1.888595
# iteration 1300 / 1500: loss 1.764294
# iteration 1400 / 1500: loss 1.797056
# training accuracy: 0.397000
# validation accuracy: 0.393000
# 93 1.007979140981134e-06 753.9095220845466
# iteration 0 / 1500: loss 27.908661
# iteration 100 / 1500: loss 19.133599
# iteration 200 / 1500: loss 14.286387
# iteration 300 / 1500: loss 11.016241
# iteration 400 / 1500: loss 8.399214
# iteration 500 / 1500: loss 6.771646
# iteration 600 / 1500: loss 5.429465
# iteration 700 / 1500: loss 4.497525
# iteration 800 / 1500: loss 3.721212
# iteration 900 / 1500: loss 3.222602
# iteration 1000 / 1500: loss 2.855889
# iteration 1100 / 1500: loss 2.534178
# iteration 1200 / 1500: loss 2.449333
# iteration 1300 / 1500: loss 2.246477
# iteration 1400 / 1500: loss 2.050874
# training accuracy: 0.403265
# validation accuracy: 0.395000
# 94 1.794754977008282e-06 1080.290413503002
# iteration 0 / 1500: loss 39.165684
# iteration 100 / 1500: loss 17.373733
# iteration 200 / 1500: loss 8.782349
# iteration 300 / 1500: loss 4.897488
# iteration 400 / 1500: loss 3.292805
# iteration 500 / 1500: loss 2.555825
# iteration 600 / 1500: loss 2.093706
# iteration 700 / 1500: loss 1.986067
# iteration 800 / 1500: loss 1.936916
# iteration 900 / 1500: loss 1.943750
# iteration 1000 / 1500: loss 1.950077
# iteration 1100 / 1500: loss 1.871277
# iteration 1200 / 1500: loss 1.842326
# iteration 1300 / 1500: loss 1.834813
# iteration 1400 / 1500: loss 1.879077
# training accuracy: 0.395204
# validation accuracy: 0.417000
# 95 1.7149977650150085e-06 1095.8804983052087
# iteration 0 / 1500: loss 40.100110
# iteration 100 / 1500: loss 17.625936
# iteration 200 / 1500: loss 9.214203
# iteration 300 / 1500: loss 5.189085
# iteration 400 / 1500: loss 3.355982
# iteration 500 / 1500: loss 2.497848
# iteration 600 / 1500: loss 2.144872
# iteration 700 / 1500: loss 2.087432
# iteration 800 / 1500: loss 1.894516
# iteration 900 / 1500: loss 1.803829
# iteration 1000 / 1500: loss 1.838444
# iteration 1100 / 1500: loss 1.890765
# iteration 1200 / 1500: loss 1.798723
# iteration 1300 / 1500: loss 1.731926
# iteration 1400 / 1500: loss 1.832631
# training accuracy: 0.395408
# validation accuracy: 0.404000
# 96 1.5469843678157729e-06 908.0352587519237
# iteration 0 / 1500: loss 34.444391
# iteration 100 / 1500: loss 17.758695
# iteration 200 / 1500: loss 10.613677
# iteration 300 / 1500: loss 6.877858
# iteration 400 / 1500: loss 4.539367
# iteration 500 / 1500: loss 3.398843
# iteration 600 / 1500: loss 2.776883
# iteration 700 / 1500: loss 2.464985
# iteration 800 / 1500: loss 2.056171
# iteration 900 / 1500: loss 2.084025
# iteration 1000 / 1500: loss 1.912393
# iteration 1100 / 1500: loss 1.963800
# iteration 1200 / 1500: loss 1.900578
# iteration 1300 / 1500: loss 1.909502
# iteration 1400 / 1500: loss 1.867200
# training accuracy: 0.401469
# validation accuracy: 0.402000
# 97 2.674870638609082e-06 1443.4084237171908
# iteration 0 / 1500: loss 50.939304
# iteration 100 / 1500: loss 11.229525
# iteration 200 / 1500: loss 3.841513
# iteration 300 / 1500: loss 2.318210
# iteration 400 / 1500: loss 1.875012
# iteration 500 / 1500: loss 1.995359
# iteration 600 / 1500: loss 1.876262
# iteration 700 / 1500: loss 1.857034
# iteration 800 / 1500: loss 1.863013
# iteration 900 / 1500: loss 1.938811
# iteration 1000 / 1500: loss 1.853839
# iteration 1100 / 1500: loss 1.928476
# iteration 1200 / 1500: loss 1.850538
# iteration 1300 / 1500: loss 1.852341
# iteration 1400 / 1500: loss 1.989438
# training accuracy: 0.369612
# validation accuracy: 0.372000
# 98 2.271775720995883e-06 975.7861723685071
# iteration 0 / 1500: loss 35.804441
# iteration 100 / 1500: loss 14.231082
# iteration 200 / 1500: loss 6.833532
# iteration 300 / 1500: loss 3.765121
# iteration 400 / 1500: loss 2.646434
# iteration 500 / 1500: loss 2.165628
# iteration 600 / 1500: loss 1.978729
# iteration 700 / 1500: loss 1.919057
# iteration 800 / 1500: loss 1.882955
# iteration 900 / 1500: loss 1.838299
# iteration 1000 / 1500: loss 1.899655
# iteration 1100 / 1500: loss 1.797789
# iteration 1200 / 1500: loss 1.922784
# iteration 1300 / 1500: loss 1.926039
# iteration 1400 / 1500: loss 1.915980
# training accuracy: 0.400469
# validation accuracy: 0.396000
# 99 2.934064149546607e-06 821.2697273321452
# iteration 0 / 1500: loss 30.759165
# iteration 100 / 1500: loss 11.444183
# iteration 200 / 1500: loss 5.329173
# iteration 300 / 1500: loss 3.252726
# iteration 400 / 1500: loss 2.367124
# iteration 500 / 1500: loss 2.018293
# iteration 600 / 1500: loss 1.869595
# iteration 700 / 1500: loss 1.850157
# iteration 800 / 1500: loss 1.861840
# iteration 900 / 1500: loss 1.856908
# iteration 1000 / 1500: loss 1.777090
# iteration 1100 / 1500: loss 1.881317
# iteration 1200 / 1500: loss 1.904065
# iteration 1300 / 1500: loss 1.887721
# iteration 1400 / 1500: loss 1.896706
# training accuracy: 0.389020
# validation accuracy: 0.399000
# lr 1.007979e-06 reg 7.539095e+02 train accuracy: 0.403265 val accuracy: 0.395000
# lr 1.024631e-06 reg 8.751243e+02 train accuracy: 0.405531 val accuracy: 0.400000
# lr 1.048435e-06 reg 1.342042e+03 train accuracy: 0.398061 val accuracy: 0.399000
# lr 1.055275e-06 reg 5.844363e+02 train accuracy: 0.405102 val accuracy: 0.406000
# lr 1.075087e-06 reg 1.061947e+03 train accuracy: 0.403286 val accuracy: 0.401000
# lr 1.089773e-06 reg 1.315307e+03 train accuracy: 0.389265 val accuracy: 0.377000
# lr 1.113744e-06 reg 6.830794e+02 train accuracy: 0.404918 val accuracy: 0.419000
# lr 1.118731e-06 reg 1.035282e+03 train accuracy: 0.396122 val accuracy: 0.398000
# lr 1.123559e-06 reg 1.412827e+03 train accuracy: 0.390592 val accuracy: 0.392000
# lr 1.145905e-06 reg 7.163797e+02 train accuracy: 0.401286 val accuracy: 0.393000
# lr 1.167755e-06 reg 9.906940e+02 train accuracy: 0.399592 val accuracy: 0.382000
# lr 1.213178e-06 reg 1.415884e+03 train accuracy: 0.388612 val accuracy: 0.385000
# lr 1.232857e-06 reg 1.387864e+03 train accuracy: 0.389857 val accuracy: 0.397000
# lr 1.283679e-06 reg 8.723600e+02 train accuracy: 0.404020 val accuracy: 0.405000
# lr 1.292752e-06 reg 1.317721e+03 train accuracy: 0.394571 val accuracy: 0.397000
# lr 1.332495e-06 reg 1.349641e+03 train accuracy: 0.393857 val accuracy: 0.388000
# lr 1.398028e-06 reg 1.113014e+03 train accuracy: 0.397673 val accuracy: 0.400000
# lr 1.421064e-06 reg 6.298954e+02 train accuracy: 0.406714 val accuracy: 0.401000
# lr 1.446328e-06 reg 7.666932e+02 train accuracy: 0.400000 val accuracy: 0.379000
# lr 1.493902e-06 reg 5.139703e+02 train accuracy: 0.409469 val accuracy: 0.401000
# lr 1.509236e-06 reg 1.455203e+03 train accuracy: 0.387347 val accuracy: 0.377000
# lr 1.515373e-06 reg 1.373536e+03 train accuracy: 0.381694 val accuracy: 0.393000
# lr 1.546984e-06 reg 9.080353e+02 train accuracy: 0.401469 val accuracy: 0.402000
# lr 1.560125e-06 reg 1.480875e+03 train accuracy: 0.392000 val accuracy: 0.390000
# lr 1.565544e-06 reg 6.003619e+02 train accuracy: 0.405755 val accuracy: 0.398000
# lr 1.575115e-06 reg 1.431092e+03 train accuracy: 0.392755 val accuracy: 0.398000
# lr 1.638550e-06 reg 8.100633e+02 train accuracy: 0.397959 val accuracy: 0.413000
# lr 1.645851e-06 reg 1.305976e+03 train accuracy: 0.389327 val accuracy: 0.388000
# lr 1.649282e-06 reg 5.913817e+02 train accuracy: 0.403714 val accuracy: 0.402000
# lr 1.714998e-06 reg 1.095880e+03 train accuracy: 0.395408 val accuracy: 0.404000
# lr 1.740384e-06 reg 1.363713e+03 train accuracy: 0.389306 val accuracy: 0.387000
# lr 1.751354e-06 reg 9.882546e+02 train accuracy: 0.391245 val accuracy: 0.391000
# lr 1.761788e-06 reg 9.967103e+02 train accuracy: 0.393102 val accuracy: 0.390000
# lr 1.778925e-06 reg 7.167699e+02 train accuracy: 0.397776 val accuracy: 0.387000
# lr 1.794755e-06 reg 1.080290e+03 train accuracy: 0.395204 val accuracy: 0.417000
# lr 1.815366e-06 reg 1.219675e+03 train accuracy: 0.390735 val accuracy: 0.404000
# lr 1.830561e-06 reg 1.280190e+03 train accuracy: 0.387429 val accuracy: 0.395000
# lr 1.836102e-06 reg 1.182666e+03 train accuracy: 0.392898 val accuracy: 0.399000
# lr 1.836379e-06 reg 1.320184e+03 train accuracy: 0.397000 val accuracy: 0.393000
# lr 1.853557e-06 reg 1.260551e+03 train accuracy: 0.385122 val accuracy: 0.393000
# lr 1.864089e-06 reg 1.446887e+03 train accuracy: 0.378878 val accuracy: 0.395000
# lr 1.876695e-06 reg 8.544719e+02 train accuracy: 0.406000 val accuracy: 0.392000
# lr 1.897847e-06 reg 8.323236e+02 train accuracy: 0.397388 val accuracy: 0.396000
# lr 1.914136e-06 reg 5.310445e+02 train accuracy: 0.402143 val accuracy: 0.394000
# lr 1.953840e-06 reg 5.567190e+02 train accuracy: 0.403122 val accuracy: 0.401000
# lr 1.966002e-06 reg 1.048563e+03 train accuracy: 0.397531 val accuracy: 0.385000
# lr 1.966486e-06 reg 1.266535e+03 train accuracy: 0.391122 val accuracy: 0.381000
# lr 2.024083e-06 reg 1.255366e+03 train accuracy: 0.385633 val accuracy: 0.383000
# lr 2.032280e-06 reg 1.134402e+03 train accuracy: 0.394796 val accuracy: 0.394000
# lr 2.116687e-06 reg 8.903340e+02 train accuracy: 0.388143 val accuracy: 0.393000
# lr 2.158336e-06 reg 1.383041e+03 train accuracy: 0.381510 val accuracy: 0.383000
# lr 2.159038e-06 reg 1.348678e+03 train accuracy: 0.387592 val accuracy: 0.407000
# lr 2.183803e-06 reg 6.185976e+02 train accuracy: 0.395898 val accuracy: 0.396000
# lr 2.205165e-06 reg 1.495984e+03 train accuracy: 0.380653 val accuracy: 0.378000
# lr 2.224981e-06 reg 1.178161e+03 train accuracy: 0.374612 val accuracy: 0.394000
# lr 2.248023e-06 reg 6.367145e+02 train accuracy: 0.383347 val accuracy: 0.373000
# lr 2.268875e-06 reg 8.113686e+02 train accuracy: 0.400000 val accuracy: 0.399000
# lr 2.271776e-06 reg 9.757862e+02 train accuracy: 0.400469 val accuracy: 0.396000
# lr 2.276450e-06 reg 1.084552e+03 train accuracy: 0.391796 val accuracy: 0.389000
# lr 2.293000e-06 reg 7.197338e+02 train accuracy: 0.391531 val accuracy: 0.403000
# lr 2.307268e-06 reg 1.289982e+03 train accuracy: 0.375694 val accuracy: 0.372000
# lr 2.342980e-06 reg 8.073849e+02 train accuracy: 0.396265 val accuracy: 0.395000
# lr 2.405362e-06 reg 1.271410e+03 train accuracy: 0.388327 val accuracy: 0.375000
# lr 2.406522e-06 reg 5.945800e+02 train accuracy: 0.394204 val accuracy: 0.380000
# lr 2.407751e-06 reg 5.843063e+02 train accuracy: 0.396612 val accuracy: 0.408000
# lr 2.408087e-06 reg 1.340150e+03 train accuracy: 0.393429 val accuracy: 0.386000
# lr 2.433289e-06 reg 1.391170e+03 train accuracy: 0.385653 val accuracy: 0.393000
# lr 2.447031e-06 reg 8.870401e+02 train accuracy: 0.380041 val accuracy: 0.398000
# lr 2.452792e-06 reg 1.165442e+03 train accuracy: 0.387633 val accuracy: 0.406000
# lr 2.481373e-06 reg 1.257992e+03 train accuracy: 0.374143 val accuracy: 0.373000
# lr 2.487605e-06 reg 7.871764e+02 train accuracy: 0.388286 val accuracy: 0.386000
# lr 2.500783e-06 reg 1.140859e+03 train accuracy: 0.384102 val accuracy: 0.391000
# lr 2.502819e-06 reg 1.096155e+03 train accuracy: 0.381102 val accuracy: 0.398000
# lr 2.552567e-06 reg 6.135250e+02 train accuracy: 0.386347 val accuracy: 0.379000
# lr 2.558060e-06 reg 1.384926e+03 train accuracy: 0.390551 val accuracy: 0.383000
# lr 2.572192e-06 reg 6.595775e+02 train accuracy: 0.396980 val accuracy: 0.394000
# lr 2.575443e-06 reg 1.407508e+03 train accuracy: 0.376143 val accuracy: 0.382000
# lr 2.594031e-06 reg 7.127888e+02 train accuracy: 0.392408 val accuracy: 0.397000
# lr 2.595708e-06 reg 7.702769e+02 train accuracy: 0.387408 val accuracy: 0.393000
# lr 2.601470e-06 reg 6.677247e+02 train accuracy: 0.383898 val accuracy: 0.387000
# lr 2.602161e-06 reg 1.102528e+03 train accuracy: 0.381633 val accuracy: 0.396000
# lr 2.614464e-06 reg 1.094032e+03 train accuracy: 0.381959 val accuracy: 0.386000
# lr 2.619934e-06 reg 1.055020e+03 train accuracy: 0.385184 val accuracy: 0.398000
# lr 2.659516e-06 reg 1.312009e+03 train accuracy: 0.388000 val accuracy: 0.393000
# lr 2.671825e-06 reg 1.417731e+03 train accuracy: 0.388388 val accuracy: 0.373000
# lr 2.674871e-06 reg 1.443408e+03 train accuracy: 0.369612 val accuracy: 0.372000
# lr 2.690666e-06 reg 5.162187e+02 train accuracy: 0.396592 val accuracy: 0.387000
# lr 2.691418e-06 reg 6.397479e+02 train accuracy: 0.403571 val accuracy: 0.401000
# lr 2.777099e-06 reg 1.183686e+03 train accuracy: 0.378571 val accuracy: 0.378000
# lr 2.781629e-06 reg 9.739421e+02 train accuracy: 0.389714 val accuracy: 0.393000
# lr 2.789115e-06 reg 6.107675e+02 train accuracy: 0.393653 val accuracy: 0.396000
# lr 2.791131e-06 reg 1.086415e+03 train accuracy: 0.379184 val accuracy: 0.367000
# lr 2.823366e-06 reg 8.793100e+02 train accuracy: 0.381918 val accuracy: 0.386000
# lr 2.874838e-06 reg 1.388040e+03 train accuracy: 0.383265 val accuracy: 0.394000
# lr 2.875366e-06 reg 1.405139e+03 train accuracy: 0.385918 val accuracy: 0.389000
# lr 2.884159e-06 reg 8.818172e+02 train accuracy: 0.386796 val accuracy: 0.384000
# lr 2.897057e-06 reg 9.014043e+02 train accuracy: 0.377714 val accuracy: 0.368000
# lr 2.934064e-06 reg 8.212697e+02 train accuracy: 0.389020 val accuracy: 0.399000
# lr 2.981522e-06 reg 8.772986e+02 train accuracy: 0.394694 val accuracy: 0.393000
# lr 2.984242e-06 reg 1.214296e+03 train accuracy: 0.374735 val accuracy: 0.375000
# best validation accuracy achieved during cross-validation: 0.419000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.394000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$True
#
#
# $\color{blue}{\textit Your Explanation:}$Because loss for SVM works only for the margin. We don't care about the distance, unless it is possitioned inside the margin.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
